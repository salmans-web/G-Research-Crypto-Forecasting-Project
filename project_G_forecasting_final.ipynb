# %%
#!pip install lightgbm
#!pip install catboost
#!pip install tensorflow
#!pip install --upgrade tensorflow
#library to use KerasClassifier
#!pip install scikeras

# %% [markdown]
# timestamp - A timestamp for the minute covered by the row.
# Asset_ID - An ID code for the cryptoasset.
# Count - The number of trades that took place this minute.
# Open - The USD price at the beginning of the minute.
# High - The highest USD price during the minute.
# Low - The lowest USD price during the minute.
# Close - The USD price at the end of the minute.
# Volume - The number of cryptoasset units traded during the minute.
# VWAP - The volume weighted average price for the minute.
# Target - 15 minute residualized returns.

# %%
######################
# Importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler , StandardScaler
from sklearn.metrics import mean_squared_error , mean_absolute_error , r2_score
from sklearn.linear_model import LogisticRegressionCV , LogisticRegression
from sklearn.model_selection import GridSearchCV , RandomizedSearchCV , cross_val_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from lightgbm import LGBMRegressor
import catboost as cb
import xgboost as xgb
import os
import matplotlib.pyplot as plt
import io
from prettytable import PrettyTable
# Importing tensorflow and keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten , Dense , Softmax , Dropout
from tensorflow.keras import optimizers
# Libraries to use ANN
import scikeras
from scikeras.wrappers import KerasRegressor

# %%
train_data = pd.read_csv("C:\\Users\\Faheem\\Downloads\\train.csv (2)\\train.csv")
train_data.head()
# Out:
#     timestamp  Asset_ID  Count        Open        High         Low  \
# 0  1514764860         2   40.0   2376.5800   2399.5000   2357.1400
# 1  1514764860         0    5.0      8.5300      8.5300      8.5300
# 2  1514764860         1  229.0  13835.1940  14013.8000  13666.1100
# 3  1514764860         5   32.0      7.6596      7.6596      7.6567
# 4  1514764860         7    5.0     25.9200     25.9200     25.8740
#
#         Close       Volume          VWAP    Target
# 0   2374.5900    19.233005   2373.116392 -0.004218
# 1      8.5300    78.380000      8.530000 -0.014399
# 2  13850.1760    31.550062  13827.062093 -0.014643
# 3      7.6576  6626.713370      7.657713 -0.013922
# 4     25.8770   121.087310     25.891363 -0.008264

# %%
btc = train_data[train_data["Asset_ID"]==1].set_index("timestamp")

# %%
btc.index.name = None

# %%
btc.head()
# Out:
#             Asset_ID  Count       Open     High       Low      Close  \
# 1514764860         1  229.0  13835.194  14013.8  13666.11  13850.176
# 1514764920         1  235.0  13835.036  14052.3  13680.00  13828.102
# 1514764980         1  528.0  13823.900  14000.4  13601.00  13801.314
# 1514765040         1  435.0  13802.512  13999.0  13576.28  13768.040
# 1514765100         1  742.0  13766.000  13955.9  13554.44  13724.914
#
#                 Volume          VWAP    Target
# 1514764860   31.550062  13827.062093 -0.014643
# 1514764920   31.046432  13840.362591 -0.015037
# 1514764980   55.061820  13806.068014 -0.010309
# 1514765040   38.780529  13783.598101 -0.008999
# 1514765100  108.501637  13735.586842 -0.008079

# %%
train_data = btc

# %%
start_data = train_data.index[0].astype('datetime64[s]')
end_data  = train_data.index[-1].astype('datetime64[s]')
print('BTC data goes from ', start_data, 'to ', end_data)
# Out:
# BTC data goes from  2018-01-01T00:01:00 to  2021-09-21T00:00:00

# %%
# plot vwap time series for both chosen assets
f = plt.figure(figsize=(15,4))

# fill missing values for BTC
#btc = train_data.reindex(range(btc.index[0],btc.index[-1]+60,60),method='pad')

ax = f.add_subplot(121)
plt.plot(btc['Open'], label='BTC open')
plt.legend()
plt.xlabel('Time')
plt.ylabel('Bitcoin Open')

ax2 = f.add_subplot(122)
ax2.plot(btc['Close'], color='red', label='BTC close')
plt.legend()
plt.xlabel('Time')
plt.ylabel('Bitcoin Close')

plt.tight_layout()
plt.show()

# %%
# Identifying the shape of the dataset
print(train_data.shape)
# Out:
# (1956282, 9)

# %%
# Finding the column names of Train Dataset
train_data.columns
# Out:
# Index(['Asset_ID', 'Count', 'Open', 'High', 'Low', 'Close', 'Volume', 'VWAP',
#        'Target'],
#       dtype='object')

# %%
# Identifying if any missing values are present in the dataset along with
# the data types of each column for train data
print("Train Dataset Info-",train_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1956282 entries, 1514764860 to 1632182400
# Data columns (total 9 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   Asset_ID  int64
#  1   Count     float64
#  2   Open      float64
#  3   High      float64
#  4   Low       float64
#  5   Close     float64
#  6   Volume    float64
#  7   VWAP      float64
#  8   Target    float64
# dtypes: float64(8), int64(1)
# memory usage: 149.3 MB
# Train Dataset Info- None

# %%
# Finding the overall statistics of the train dataset
train_data.describe(include="all")
# Out:
#         Asset_ID         Count          Open          High           Low  \
# count  1956282.0  1.956282e+06  1.956282e+06  1.956282e+06  1.956282e+06
# mean         1.0  1.082390e+03  1.561112e+04  1.565181e+04  1.557804e+04
# std          0.0  1.601813e+03  1.512141e+04  1.513203e+04  1.510627e+04
# min          1.0  1.000000e+00  3.149657e+03  3.176910e+03  3.120000e+03
# 25%          1.0  2.980000e+02  6.848250e+03  6.865382e+03  6.835622e+03
# 50%          1.0  5.630000e+02  9.206021e+03  9.222400e+03  9.191175e+03
# 75%          1.0  1.259000e+03  1.346695e+04  1.352072e+04  1.340000e+04
# max          1.0  8.747800e+04  6.480594e+04  6.490000e+04  6.467053e+04
#
#               Close        Volume          VWAP        Target
# count  1.956282e+06  1.956282e+06  1.956282e+06  1.955978e+06
# mean   1.561112e+04  9.284999e+01  1.561100e+04 -1.559993e-06
# std    1.512144e+04  1.554052e+02  1.512129e+04  2.013754e-03
# min    3.151545e+03  1.000000e-04  3.152326e+03 -7.255649e-02
# 25%    6.848072e+03  3.020642e+01  6.848265e+03 -8.163170e-04
# 50%    9.205980e+03  5.280397e+01  9.205946e+03 -1.916906e-05
# 75%    1.346706e+04  9.767651e+01  1.346745e+04  7.718871e-04
# max    6.480854e+04  1.040500e+04  6.479982e+04  9.278919e-02

# %%
# Finding the overall unique values in the Target column of Train Dataset -
# 0 represents a customer who did not respond to the campaign and
# 1 represents a customer who did respond to the campaign
train_data["Target"].value_counts(sort=False)
# Out:
# Target
# -0.014643    1
# -0.015037    1
# -0.010309    1
# -0.008999    1
# -0.008079    1
#             ..
#  0.002084    1
#  0.003246    1
#  0.003108    1
#  0.002770    1
#  0.002726    1
# Name: count, Length: 1955977, dtype: int64

# %%
print("Checking for missing values in Train Data: \n",train_data.isnull().sum())
# Out:
# Checking for missing values in Train Data:
#  Asset_ID      0
# Count         0
# Open          0
# High          0
# Low           0
# Close         0
# Volume        0
# VWAP          0
# Target      304
# dtype: int64

# %%
train_data = train_data.dropna(axis=0)

# %% [markdown]
# #### EDA:

# %% [markdown]
# #### Univariate Analysis:

# %%
#sns.histplot(data = train_data , bins=20)
train_data.hist( bins = 20 , figsize = ( 20 , 20 ) )
plt.show()

# %% [markdown]
# #### Bivariate- Analysis:

# %%
plt.figure(figsize=(18, 14))

# Open vs. Close
plt.subplot(3, 3, 1)
plt.scatter(train_data['Open'], train_data['Close'], alpha=0.5)
plt.title('Open vs. Close')
plt.xlabel('Open')
plt.ylabel('Close')

# High vs. Low
plt.subplot(3, 3, 2)
plt.scatter(train_data['High'], train_data['Low'], alpha=0.5)
plt.title('High vs. Low')
plt.xlabel('High')
plt.ylabel('Low')

# Volume vs. VWAP
plt.subplot(3, 3, 3)
plt.scatter(train_data['Volume'], train_data['VWAP'], alpha=0.5)
plt.title('Volume vs. VWAP')
plt.xlabel('Volume')
plt.ylabel('VWAP')

# Open vs. Volume
plt.subplot(3, 3, 4)
plt.scatter(train_data['Open'], train_data['Volume'], alpha=0.5)
plt.title('Open vs. Volume')
plt.xlabel('Open')
plt.ylabel('Volume')

# Close vs. Volume
plt.subplot(3, 3, 5)
plt.scatter(train_data['Close'], train_data['Volume'], alpha=0.5)
plt.title('Close vs. Volume')
plt.xlabel('Close')
plt.ylabel('Volume')

# High vs. Volume
plt.subplot(3, 3, 6)
plt.scatter(train_data['High'], train_data['Volume'], alpha=0.5)
plt.title('High vs. Volume')
plt.xlabel('High')
plt.ylabel('Volume')

# Low vs. Volume
plt.subplot(3, 3, 7)
plt.scatter(train_data['Low'], train_data['Volume'], alpha=0.5)
plt.title('Low vs. Volume')
plt.xlabel('Low')
plt.ylabel('Volume')

# VWAP vs. Target
plt.subplot(3, 3, 8)
plt.scatter(train_data['VWAP'], train_data['Target'], alpha=0.5)
plt.title('VWAP vs. Target')
plt.xlabel('VWAP')
plt.ylabel('Target')

# Target vs. Close
plt.subplot(3, 3, 9)
plt.scatter(train_data['Target'], train_data['Close'], alpha=0.5)
plt.title('Target vs. Close')
plt.xlabel('Target')
plt.ylabel('Close')

plt.tight_layout()
plt.show()

# %%
plt.figure( figsize = ( 7, 7 ) )
matrix = train_data.loc[:, train_data.columns != 'Asset_ID'].corr(method='pearson')
#sns.heatmap(matrix, annot=True)
#
#Pearson’s Correlations
sns.heatmap(matrix, annot=True)
#
plt.show()

# %%
numerical_columns = [ 'Count','Open','High','Low', 'Close', 'Volume', 'VWAP' ]

target_column     = "Target"

working_columns   = numerical_columns

print("Target Column-",target_column)
print("\n")
print("Working Column-",working_columns)
# Out:
# Target Column- Target
#
#
# Working Column- ['Count', 'Open', 'High', 'Low', 'Close', 'Volume', 'VWAP']

# %%
upper_shadow = lambda asset: asset.High - np.maximum(asset.Close,asset.Open)
lower_shadow = lambda asset: np.minimum(asset.Close,asset.Open)- asset.Low

# Creating features to calculate upper shadow and lower shadow
train_data['upper_shadow'] = upper_shadow(train_data)
train_data['lower_shadow'] = lower_shadow(train_data)
# Out:
# C:\Users\Faheem\AppData\Local\Temp\ipykernel_31292\4218962908.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['upper_shadow'] = upper_shadow(train_data)
# C:\Users\Faheem\AppData\Local\Temp\ipykernel_31292\4218962908.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['lower_shadow'] = lower_shadow(train_data)

# %%
# Updating the working_columns and numerical_columns
working_columns.append('upper_shadow')
working_columns.append('lower_shadow')
print(working_columns)
# Out:
# ['Count', 'Open', 'High', 'Low', 'Close', 'Volume', 'VWAP', 'upper_shadow', 'lower_shadow']

# %%
X = train_data[working_columns]
y = train_data[target_column]

print(f"Shape of X: {X.shape}")
print(f"Shape of y: {y.shape}")
# Out:
# Shape of X: (1955978, 9)
# Shape of y: (1955978,)

# %%
# Finding the importance of features
# linear regression feature importance
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
from matplotlib import pyplot
# define dataset
X, y = make_regression(n_samples=1000, n_features=9, n_informative=9, random_state=1)
# define the model
model = LinearRegression()
# fit the model
model.fit(X, y)

# get importance
importance = model.coef_

## summarize feature importance
importance_values = []
for i,v in enumerate(importance):
    importance_values.append([i,v])
importance_values.sort(key = lambda x: x[1],reverse=True)
for i,v in importance_values:
    print('Feature: %-15s, Score: %.5f' % (working_columns[i],v))
## plot feature importance
plt.figure(figsize=(15,10))
plt.xticks(rotation=90)
sns.barplot( y = [ value for x,value in importance_values ] ,
             x = [ working_columns[x] for x,value in importance_values ] )
plt.tight_layout()
# Out:
# Feature: Low            , Score: 95.06270
# Feature: Volume         , Score: 79.75863
# Feature: upper_shadow   , Score: 76.46241
# Feature: VWAP           , Score: 72.74732
# Feature: High           , Score: 62.38208
# Feature: Close          , Score: 45.43334
# Feature: lower_shadow   , Score: 31.83850
# Feature: Count          , Score: 17.56772
# Feature: Open           , Score: 16.55053
# C:\Users\Faheem\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)

# %%
X = train_data[working_columns]
y = train_data[target_column]

print(f"Shape of X: {X.shape}")
print(f"Shape of y: {y.shape}")

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)
print("X_train.shape: ", X_train.shape)
print("X_test.shape: ", X_test.shape)
print("y_train.shape: ", y_train.shape)
print("y_test.shape: ", y_test.shape)
# Out:
# Shape of X: (1955978, 9)
# Shape of y: (1955978,)
# X_train.shape:  (1564782, 9)
# X_test.shape:  (391196, 9)
# y_train.shape:  (1564782,)
# y_test.shape:  (391196,)

# %%
# Create numerical pipeline to transform numerical values
numerical_list_columns = list(working_columns)

numerical_pipeline = Pipeline([('missing',SimpleImputer(strategy='mean')),('scaler', StandardScaler())])

pipeline_total = ColumnTransformer( [ ("numerical", numerical_pipeline, numerical_list_columns) ] )

# %%
# Transformed dataset after creating pipelines
pipeline_total.fit(X_train)
X_train = pipeline_total.transform(X_train)
X_test = pipeline_total.transform(X_test)
print(f"New Transformed Shape of X_Train: {X_train.shape}")
print(f"New Transformed Shape of X_test: {X_test.shape}")
# Out:
# New Transformed Shape of X_Train: (1564782, 9)
# New Transformed Shape of X_test: (391196, 9)

# %%
# Different Model Metrics
def model_eval_scores(y_test,y_pred):
    #mean_squared_error , mean_absolute_error , r2_score
    print( "Mean Squared  Error : ",f"{ mean_squared_error( y_test  , y_pred ) }" )
    print( "Mean Absolute Error : ",f"{ mean_absolute_error( y_test , y_pred ) }" )
    print( "R2 Score            : ",f"{ r2_score( y_test , y_pred ) }" )
    return mean_squared_error( y_test , y_pred ) , r2_score( y_test , y_pred )

# %%
mean_s_error = []
R2_score = []
models = []

# %%
# Saving results
def update_scores( mean_s_error_v , R2_score_v , model ):
  if model in models:
    index = models.index( model )
    mean_s_error[index] = mean_s_error_v
    R2_score[index]     = R2_score_v
  else:
    models.append( model )
    mean_s_error.append( mean_s_error_v )
    R2_score.append( R2_score_v )

# %%
# Displaying Results
def view_scores():
  print("The scores are:\n")
  t = PrettyTable()
  t.add_column('Model', models)
  t.add_column('Mean Squared  Error', mean_s_error)
  t.add_column('R2 Score', R2_score)
  print(t)

# %% [markdown]
# # 1. Linear Regresion

# %%
linear_regression_predictor = LinearRegression()
linear_regression_predictor.fit(X_train,y_train)
y_pred_linear_regression = linear_regression_predictor.predict(X_test)

# %%
# Evaluation metrics for Decision Tree
MSE_eval_score_linear_regression , R2_eval_score_linear_regression = model_eval_scores(y_test,y_pred_linear_regression)
# Out:
# Mean Squared  Error :  4.077755929909384e-06
# Mean Absolute Error :  0.0012380808879060797
# R2 Score            :  0.0010677655595967561

# %%
print(y_test.shape)
print(y_pred_linear_regression.shape)
x = np.arange(len(y_test))
# Out:
# (391196,)
# (391196,)

# %%
# Appending the Model and Validation Score in a stored list
update_scores(MSE_eval_score_linear_regression,R2_eval_score_linear_regression,'LinearRegression')

# %%
# Calling the function to view the list of machine learning models executed till now and their respective scores
view_scores()
# Out:
# The scores are:
#
# +------------------+-----------------------+-----------------------+
# |      Model       |  Mean Squared  Error  |        R2 Score       |
# +------------------+-----------------------+-----------------------+
# | LinearRegression | 4.077755929909384e-06 | 0.0010677655595967561 |
# +------------------+-----------------------+-----------------------+

# %%
# plot lines 
plt.plot( x , y_test , label = "y test" )
plt.plot( x , y_pred_linear_regression , label = "y predicted" )
plt.legend() 
plt.show()

# %% [markdown]
# # 2. Decision Tree

# %%
decision_tree_regressor = DecisionTreeRegressor(random_state=0)
decision_tree_regressor.fit(X_train,y_train)
y_pred_decision_tree_regressor = decision_tree_regressor.predict(X_test)

# %%
# Evaluation metrics for Decision Tree
MSE_eval_score_decision_tree_regressor ,R2_eval_score_decision_tree_regressor = model_eval_scores(y_test,y_pred_decision_tree_regressor)
# Out:
# Mean Squared  Error :  7.946220155825404e-06
# Mean Absolute Error :  0.0017924335129276458
# R2 Score            :  -0.9465940561553996

# %%
print(y_test.shape)
print(y_pred_decision_tree_regressor.shape)
x = np.arange(len(y_test))
# Out:
# (391196,)
# (391196,)

# %%
# Appending the Model and Validation Score in a stored list
update_scores(MSE_eval_score_decision_tree_regressor,R2_eval_score_decision_tree_regressor,'DecisionTree')

# %%
# Calling the function to view the list of machine learning models executed till now and their respective scores
view_scores()
# Out:
# The scores are:
#
# +------------------+-----------------------+-----------------------+
# |      Model       |  Mean Squared  Error  |        R2 Score       |
# +------------------+-----------------------+-----------------------+
# | LinearRegression | 4.077755929909384e-06 | 0.0010677655595967561 |
# |   DecisionTree   | 7.946220155825404e-06 |  -0.9465940561553996  |
# +------------------+-----------------------+-----------------------+

# %%
# plot lines 
plt.plot( x , y_test , label = "y test" )
plt.plot( x , y_pred_decision_tree_regressor , label = "y predicted" )
plt.legend() 
plt.show()

# %% [markdown]
# # 3. Random Forest

# %%
random_forest = RandomForestRegressor(max_depth=2 , random_state=3)
random_forest.fit(X_train,y_train)
y_pred_randomforest_regressor = random_forest.predict(X_test)

# %%
# Evaluation metrics for Random Forest
MSE_eval_score_randomforest_regressor , R2_eval_score_randomforest_regressor = model_eval_scores(y_test,y_pred_randomforest_regressor)
# Out:
# Mean Squared  Error :  4.071814065767409e-06
# Mean Absolute Error :  0.001238530056171291
# R2 Score            :  0.002523350377841793

# %%
print(y_test.shape)
print(y_pred_randomforest_regressor.shape)
x = np.arange(len(y_test))
# Out:
# (391196,)
# (391196,)

# %%
# Appending the Model and Validation Score in a stored list
update_scores(MSE_eval_score_randomforest_regressor,R2_eval_score_randomforest_regressor,'RandomForest')

# %%
# Calling the function to view the list of machine learning models executed till now and their respective scores
view_scores()
# Out:
# The scores are:
#
# +------------------+-----------------------+-----------------------+
# |      Model       |  Mean Squared  Error  |        R2 Score       |
# +------------------+-----------------------+-----------------------+
# | LinearRegression | 4.077755929909384e-06 | 0.0010677655595967561 |
# |   DecisionTree   | 7.946220155825404e-06 |  -0.9465940561553996  |
# |   RandomForest   | 4.071814065767409e-06 |  0.002523350377841793 |
# +------------------+-----------------------+-----------------------+

# %%
# plot lines 
plt.plot( x , y_test , label = "y test" )
plt.plot( x , y_pred_randomforest_regressor , label = "y predicted" )
plt.legend() 
plt.show()

# %% [markdown]
# # 4. KNeighbors Regressor

# %%
kneigh = KNeighborsRegressor(n_neighbors = 7)
kneigh.fit(X_train,y_train)
y_pred_kneigh_regressor = kneigh.predict(X_test)

# %%
# Evaluation metrics for Random Forest
MSE_eval_score_kneigh_regressor , R2_eval_score_kneigh_regressor = model_eval_scores(y_test,y_pred_kneigh_regressor)
# Out:
# Mean Squared  Error :  4.528346542971248e-06
# Mean Absolute Error :  0.0013481201524392099
# R2 Score            :  -0.10931389917475176

# %%
print(y_test.shape)
print(y_pred_kneigh_regressor.shape)
x = np.arange(len(y_test))
# Out:
# (391196,)
# (391196,)

# %%
# Appending the Model and Validation Score in a stored list
update_scores( MSE_eval_score_kneigh_regressor , R2_eval_score_kneigh_regressor ,'KNeighbors')

# %%
# Calling the function to view the list of machine learning models executed till now and their respective scores
view_scores()
# Out:
# The scores are:
#
# +------------------+-----------------------+-----------------------+
# |      Model       |  Mean Squared  Error  |        R2 Score       |
# +------------------+-----------------------+-----------------------+
# | LinearRegression | 4.077755929909384e-06 | 0.0010677655595967561 |
# |   DecisionTree   | 7.946220155825404e-06 |  -0.9465940561553996  |
# |   RandomForest   | 4.071814065767409e-06 |  0.002523350377841793 |
# |    KNeighbors    | 4.528346542971248e-06 |  -0.10931389917475176 |
# +------------------+-----------------------+-----------------------+

# %%
# plot lines 
plt.plot( x , y_test , label = "y test" )
plt.plot( x , y_pred_kneigh_regressor , label = "y predicted" )
plt.legend() 
plt.show()

# %% [markdown]
# # 5. Adaboost

# %%
adaboostRegressor = AdaBoostRegressor(random_state=0, n_estimators=100)
adaboostRegressor.fit(X_train,y_train)
y_pred_adaboost_regressor = adaboostRegressor.predict(X_test)

# %%
# Evaluation metrics for Adaboost Regressor
MSE_eval_score_adaboost_regressor , R2_eval_score_adaboost_regressor = model_eval_scores(y_test,y_pred_adaboost_regressor)
# Out:
# Mean Squared  Error :  1.893919327645558e-05
# Mean Absolute Error :  0.0022705686109470145
# R2 Score            :  -3.639554446940342

# %%
print(y_test.shape)
print(y_pred_adaboost_regressor.shape)
x = np.arange(len(y_test))
# Out:
# (391196,)
# (391196,)

# %%
# Appending the Model and Validation Score in a stored list
update_scores( MSE_eval_score_adaboost_regressor , R2_eval_score_adaboost_regressor ,'Adaboost_Regressor')

# %%
# Calling the function to view the list of machine learning models executed till now and their respective scores
view_scores()
# Out:
# The scores are:
#
# +--------------------+-----------------------+-----------------------+
# |       Model        |  Mean Squared  Error  |        R2 Score       |
# +--------------------+-----------------------+-----------------------+
# |  LinearRegression  | 4.077755929909384e-06 | 0.0010677655595967561 |
# |    DecisionTree    | 7.946220155825404e-06 |  -0.9465940561553996  |
# |    RandomForest    | 4.071814065767409e-06 |  0.002523350377841793 |
# |     KNeighbors     | 4.528346542971248e-06 |  -0.10931389917475176 |
# | Adaboost_Regressor | 1.893919327645558e-05 |   -3.639554446940342  |
# +--------------------+-----------------------+-----------------------+

# %%
# plot lines 
plt.plot( x , y_test , label = "y test" )
plt.plot( x , y_pred_adaboost_regressor , label = "y predicted" )
plt.legend() 
plt.show()

# %% [markdown]
# # 6. Gradient Boosting

# %%
Gboost_regressor = GradientBoostingRegressor()
Gboost_regressor.fit(X_train,y_train)
y_pred_Gboost_regressor = Gboost_regressor.predict(X_test)

# %%
# Evaluation metrics for Adaboost Regressor
MSE_eval_score_Gboost_regressor , R2_eval_score_Gboost_regressor = model_eval_scores(y_test,y_pred_Gboost_regressor)
# Out:
# Mean Squared  Error :  4.051445837256448e-06
# Mean Absolute Error :  0.0012372303345797482
# R2 Score            :  0.007512977115629149

# %%
print(y_test.shape)
print(y_pred_Gboost_regressor.shape)
x = np.arange(len(y_test))
# Out:
# (391196,)
# (391196,)

# %%
# Appending the Model and Validation Score in a stored list
update_scores( MSE_eval_score_Gboost_regressor , R2_eval_score_Gboost_regressor ,'Gradient_boost_Regressor')

# %%
# Calling the function to view the list of machine learning models executed till now and their respective scores
view_scores()
# Out:
# The scores are:
#
# +--------------------------+-----------------------+-----------------------+
# |          Model           |  Mean Squared  Error  |        R2 Score       |
# +--------------------------+-----------------------+-----------------------+
# |     LinearRegression     | 4.077768814176103e-06 | 0.0010646092869888157 |
# |       DecisionTree       | 7.946220155825404e-06 |  -0.9465940561553996  |
# |       GridSearchCV       | 4.076280981000996e-06 | 0.0014290853722748187 |
# |       RandomForest       | 4.071814065767409e-06 |  0.002523350377841793 |
# |        KNeighbors        | 4.528346542971248e-06 |  -0.10931389917475176 |
# |    Adaboost_Regressor    | 1.893919327645558e-05 |   -3.639554446940342  |
# | Gradient_boost_Regressor | 4.051445837256448e-06 |  0.007512977115629149 |
# +--------------------------+-----------------------+-----------------------+

# %%
# plot lines 
plt.plot( x , y_test , label = "y test" )
plt.plot( x , y_pred_Gboost_regressor , label = "y predicted" )
plt.legend() 
plt.show()

# %% [markdown]
# # 7. XG Boost

# %%
XGboostRegressor = xgb.XGBRegressor()
XGboostRegressor.fit(X_train,y_train)
y_pred_XGboost_regressor = XGboostRegressor.predict(X_test)

# %%
# Evaluation metrics for Adaboost Regressor
MSE_eval_score_XGboost_regressor , R2_eval_score_XGboost_regressor = model_eval_scores(y_test,y_pred_XGboost_regressor)
# Out:
# Mean Squared  Error :  4.012689507663918e-06
# Mean Absolute Error :  0.0012352461067571604
# R2 Score            :  0.017007156655559297

# %%
print(y_test.shape)
print(y_pred_XGboost_regressor.shape)
x = np.arange(len(y_test))
# Out:
# (391196,)
# (391196,)

# %%
# Appending the Model and Validation Score in a stored list
update_scores( MSE_eval_score_XGboost_regressor , R2_eval_score_XGboost_regressor ,'XGboost_Regressor')

# %%
# Calling the function to view the list of machine learning models executed till now and their respective scores
view_scores()
# Out:
# The scores are:
#
# +--------------------------+-----------------------+-----------------------+
# |          Model           |  Mean Squared  Error  |        R2 Score       |
# +--------------------------+-----------------------+-----------------------+
# |     LinearRegression     | 4.077768814176103e-06 | 0.0010646092869888157 |
# |       DecisionTree       | 7.946220155825404e-06 |  -0.9465940561553996  |
# |       GridSearchCV       | 4.076280981000996e-06 | 0.0014290853722748187 |
# |       RandomForest       | 4.071814065767409e-06 |  0.002523350377841793 |
# |        KNeighbors        | 4.528346542971248e-06 |  -0.10931389917475176 |
# |    Adaboost_Regressor    | 1.893919327645558e-05 |   -3.639554446940342  |
# | Gradient_boost_Regressor | 4.051445837256448e-06 |  0.007512977115629149 |
# |    XGboost_Regressor     | 4.012689507663918e-06 |  0.017007156655559297 |
# +--------------------------+-----------------------+-----------------------+

# %%
# plot lines 
plt.plot( x , y_test , label = "y test" )
plt.plot( x , y_pred_XGboost_regressor , label = "y predicted" )
plt.legend() 
plt.show()

# %% [markdown]
# # 8. Light GBM

# %%
#######
# laoding model
LGBM_regressor = LGBMRegressor()
LGBM_regressor.fit(X_train,y_train)
y_pred_LGBM_regressor = LGBM_regressor.predict(X_test)
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.071949 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 1564782, number of used features: 9
# [LightGBM] [Info] Start training from score -0.000003

# %%
# Evaluation metrics for Adaboost Regressor
MSE_eval_score_LGBM_regressor , R2_eval_score_LGBM_regressor = model_eval_scores(y_test,y_pred_LGBM_regressor)
# Out:
# Mean Squared  Error :  4.030760195289275e-06
# Mean Absolute Error :  0.0012357634060418394
# R2 Score            :  0.012580360967502258

# %%
print(y_test.shape)
print(y_pred_LGBM_regressor.shape)
x = np.arange(len(y_test))
# Out:
# (391196,)
# (391196,)

# %%
# Appending the Model and Validation Score in a stored list
update_scores( MSE_eval_score_LGBM_regressor , R2_eval_score_LGBM_regressor ,'LGBM_Regressor')

# %%
# Calling the function to view the list of machine learning models executed till now and their respective scores
view_scores()
# Out:
# The scores are:
#
# +--------------------------+-----------------------+-----------------------+
# |          Model           |  Mean Squared  Error  |        R2 Score       |
# +--------------------------+-----------------------+-----------------------+
# |     LinearRegression     | 4.077768814176103e-06 | 0.0010646092869888157 |
# |       DecisionTree       | 7.946220155825404e-06 |  -0.9465940561553996  |
# |       GridSearchCV       | 4.076280981000996e-06 | 0.0014290853722748187 |
# |       RandomForest       | 4.071814065767409e-06 |  0.002523350377841793 |
# |        KNeighbors        | 4.528346542971248e-06 |  -0.10931389917475176 |
# |    Adaboost_Regressor    | 1.893919327645558e-05 |   -3.639554446940342  |
# | Gradient_boost_Regressor | 4.051445837256448e-06 |  0.007512977115629149 |
# |    XGboost_Regressor     | 4.012689507663918e-06 |  0.017007156655559297 |
# |      LGBM_Regressor      | 4.030760195289275e-06 |  0.012580360967502258 |
# +--------------------------+-----------------------+-----------------------+

# %%
# plot lines 
plt.plot( x , y_test , label = "y test" )
plt.plot( x , y_pred_XGboost_regressor , label = "y predicted" )
plt.legend() 
plt.show()

# %% [markdown]
# # 9. CatBoost regressor

# %%
#######
# laoding model
CATBOOST_regressor = cb.CatBoostRegressor(loss_function="RMSE")
CATBOOST_regressor.fit(X_train,y_train)
y_pred_CATBOOST_regressor = CATBOOST_regressor.predict(X_test)
# Out:
# Learning rate set to 0.130889
# 0:	learn: 0.0020117	total: 276ms	remaining: 4m 35s
# 1:	learn: 0.0020113	total: 387ms	remaining: 3m 13s
# 2:	learn: 0.0020109	total: 478ms	remaining: 2m 38s
# 3:	learn: 0.0020107	total: 573ms	remaining: 2m 22s
# 4:	learn: 0.0020103	total: 659ms	remaining: 2m 11s
# 5:	learn: 0.0020100	total: 746ms	remaining: 2m 3s
# 6:	learn: 0.0020096	total: 853ms	remaining: 2m 1s
# 7:	learn: 0.0020092	total: 944ms	remaining: 1m 57s
# 8:	learn: 0.0020090	total: 1.06s	remaining: 1m 56s
# 9:	learn: 0.0020085	total: 1.16s	remaining: 1m 54s
# 10:	learn: 0.0020082	total: 1.25s	remaining: 1m 52s
# 11:	learn: 0.0020080	total: 1.36s	remaining: 1m 52s
# 12:	learn: 0.0020078	total: 1.46s	remaining: 1m 50s
# 13:	learn: 0.0020076	total: 1.57s	remaining: 1m 50s
# 14:	learn: 0.0020075	total: 1.68s	remaining: 1m 50s
# 15:	learn: 0.0020074	total: 1.78s	remaining: 1m 49s
# 16:	learn: 0.0020071	total: 1.89s	remaining: 1m 49s
# 17:	learn: 0.0020069	total: 1.99s	remaining: 1m 48s
# 18:	learn: 0.0020067	total: 2.12s	remaining: 1m 49s
# 19:	learn: 0.0020066	total: 2.24s	remaining: 1m 49s
# 20:	learn: 0.0020064	total: 2.36s	remaining: 1m 50s
# 21:	learn: 0.0020062	total: 2.48s	remaining: 1m 50s
# 22:	learn: 0.0020060	total: 2.58s	remaining: 1m 49s
# 23:	learn: 0.0020058	total: 2.7s	remaining: 1m 49s
# 24:	learn: 0.0020057	total: 2.81s	remaining: 1m 49s
# 25:	learn: 0.0020056	total: 2.92s	remaining: 1m 49s
# 26:	learn: 0.0020055	total: 3.02s	remaining: 1m 48s
# 27:	learn: 0.0020053	total: 3.14s	remaining: 1m 48s
# 28:	learn: 0.0020053	total: 3.26s	remaining: 1m 49s
# 29:	learn: 0.0020052	total: 3.38s	remaining: 1m 49s
# 30:	learn: 0.0020051	total: 3.5s	remaining: 1m 49s
# 31:	learn: 0.0020050	total: 3.63s	remaining: 1m 49s
# 32:	learn: 0.0020049	total: 3.81s	remaining: 1m 51s
# 33:	learn: 0.0020047	total: 3.93s	remaining: 1m 51s
# 34:	learn: 0.0020046	total: 4.04s	remaining: 1m 51s
# 35:	learn: 0.0020045	total: 4.16s	remaining: 1m 51s
# 36:	learn: 0.0020043	total: 4.25s	remaining: 1m 50s
# 37:	learn: 0.0020042	total: 4.35s	remaining: 1m 50s
# 38:	learn: 0.0020041	total: 4.45s	remaining: 1m 49s
# 39:	learn: 0.0020040	total: 4.55s	remaining: 1m 49s
# 40:	learn: 0.0020040	total: 4.68s	remaining: 1m 49s
# 41:	learn: 0.0020039	total: 4.78s	remaining: 1m 48s
# 42:	learn: 0.0020037	total: 4.87s	remaining: 1m 48s
# 43:	learn: 0.0020035	total: 4.98s	remaining: 1m 48s
# 44:	learn: 0.0020035	total: 5.09s	remaining: 1m 48s
# 45:	learn: 0.0020033	total: 5.19s	remaining: 1m 47s
# 46:	learn: 0.0020030	total: 5.28s	remaining: 1m 47s
# 47:	learn: 0.0020028	total: 5.37s	remaining: 1m 46s
# 48:	learn: 0.0020027	total: 5.47s	remaining: 1m 46s
# 49:	learn: 0.0020026	total: 5.57s	remaining: 1m 45s
# 50:	learn: 0.0020025	total: 5.67s	remaining: 1m 45s
# 51:	learn: 0.0020024	total: 5.76s	remaining: 1m 45s
# 52:	learn: 0.0020023	total: 5.86s	remaining: 1m 44s
# 53:	learn: 0.0020021	total: 5.96s	remaining: 1m 44s
# 54:	learn: 0.0020020	total: 6.08s	remaining: 1m 44s
# 55:	learn: 0.0020020	total: 6.28s	remaining: 1m 45s
# 56:	learn: 0.0020019	total: 6.43s	remaining: 1m 46s
# 57:	learn: 0.0020018	total: 6.57s	remaining: 1m 46s
# 58:	learn: 0.0020018	total: 6.7s	remaining: 1m 46s
# 59:	learn: 0.0020015	total: 6.81s	remaining: 1m 46s
# 60:	learn: 0.0020014	total: 6.95s	remaining: 1m 46s
# 61:	learn: 0.0020012	total: 7.07s	remaining: 1m 46s
# 62:	learn: 0.0020010	total: 7.2s	remaining: 1m 47s
# 63:	learn: 0.0020009	total: 7.32s	remaining: 1m 47s
# 64:	learn: 0.0020007	total: 7.43s	remaining: 1m 46s
# 65:	learn: 0.0020007	total: 7.55s	remaining: 1m 46s
# 66:	learn: 0.0020006	total: 7.67s	remaining: 1m 46s
# 67:	learn: 0.0020004	total: 7.79s	remaining: 1m 46s
# 68:	learn: 0.0020003	total: 7.93s	remaining: 1m 46s
# 69:	learn: 0.0020003	total: 8.04s	remaining: 1m 46s
# 70:	learn: 0.0020002	total: 8.17s	remaining: 1m 46s
# 71:	learn: 0.0020001	total: 8.31s	remaining: 1m 47s
# 72:	learn: 0.0020000	total: 8.45s	remaining: 1m 47s
# 73:	learn: 0.0019999	total: 8.55s	remaining: 1m 47s
# 74:	learn: 0.0019999	total: 8.7s	remaining: 1m 47s
# 75:	learn: 0.0019998	total: 8.84s	remaining: 1m 47s
# 76:	learn: 0.0019998	total: 8.98s	remaining: 1m 47s
# 77:	learn: 0.0019997	total: 9.1s	remaining: 1m 47s
# 78:	learn: 0.0019996	total: 9.24s	remaining: 1m 47s
# 79:	learn: 0.0019995	total: 9.37s	remaining: 1m 47s
# 80:	learn: 0.0019993	total: 9.51s	remaining: 1m 47s
# 81:	learn: 0.0019992	total: 9.62s	remaining: 1m 47s
# 82:	learn: 0.0019992	total: 9.74s	remaining: 1m 47s
# 83:	learn: 0.0019990	total: 9.88s	remaining: 1m 47s
# 84:	learn: 0.0019989	total: 10s	remaining: 1m 47s
# 85:	learn: 0.0019988	total: 10.1s	remaining: 1m 47s
# 86:	learn: 0.0019987	total: 10.3s	remaining: 1m 47s
# 87:	learn: 0.0019987	total: 10.4s	remaining: 1m 47s
# 88:	learn: 0.0019986	total: 10.5s	remaining: 1m 47s
# 89:	learn: 0.0019985	total: 10.6s	remaining: 1m 47s
# 90:	learn: 0.0019985	total: 10.8s	remaining: 1m 47s
# 91:	learn: 0.0019984	total: 10.9s	remaining: 1m 47s
# 92:	learn: 0.0019984	total: 11s	remaining: 1m 47s
# 93:	learn: 0.0019983	total: 11.1s	remaining: 1m 47s
# 94:	learn: 0.0019982	total: 11.3s	remaining: 1m 47s
# 95:	learn: 0.0019982	total: 11.4s	remaining: 1m 47s
# 96:	learn: 0.0019981	total: 11.6s	remaining: 1m 47s
# 97:	learn: 0.0019981	total: 11.7s	remaining: 1m 47s
# 98:	learn: 0.0019978	total: 11.8s	remaining: 1m 47s
# 99:	learn: 0.0019976	total: 11.9s	remaining: 1m 47s
# 100:	learn: 0.0019976	total: 12s	remaining: 1m 47s
# 101:	learn: 0.0019974	total: 12.2s	remaining: 1m 47s
# 102:	learn: 0.0019973	total: 12.3s	remaining: 1m 46s
# 103:	learn: 0.0019973	total: 12.4s	remaining: 1m 46s
# 104:	learn: 0.0019972	total: 12.5s	remaining: 1m 46s
# 105:	learn: 0.0019971	total: 12.7s	remaining: 1m 46s
# 106:	learn: 0.0019971	total: 12.8s	remaining: 1m 46s
# 107:	learn: 0.0019970	total: 12.9s	remaining: 1m 46s
# 108:	learn: 0.0019969	total: 13s	remaining: 1m 46s
# 109:	learn: 0.0019968	total: 13.1s	remaining: 1m 46s
# 110:	learn: 0.0019968	total: 13.3s	remaining: 1m 46s
# 111:	learn: 0.0019967	total: 13.4s	remaining: 1m 46s
# 112:	learn: 0.0019966	total: 13.5s	remaining: 1m 46s
# 113:	learn: 0.0019965	total: 13.7s	remaining: 1m 46s
# 114:	learn: 0.0019965	total: 13.8s	remaining: 1m 46s
# 115:	learn: 0.0019964	total: 13.9s	remaining: 1m 46s
# 116:	learn: 0.0019963	total: 14s	remaining: 1m 45s
# 117:	learn: 0.0019962	total: 14.2s	remaining: 1m 45s
# 118:	learn: 0.0019960	total: 14.3s	remaining: 1m 45s
# 119:	learn: 0.0019959	total: 14.4s	remaining: 1m 45s
# 120:	learn: 0.0019957	total: 14.5s	remaining: 1m 45s
# 121:	learn: 0.0019956	total: 14.7s	remaining: 1m 45s
# 122:	learn: 0.0019956	total: 14.8s	remaining: 1m 45s
# 123:	learn: 0.0019954	total: 14.9s	remaining: 1m 45s
# 124:	learn: 0.0019953	total: 15.1s	remaining: 1m 45s
# 125:	learn: 0.0019952	total: 15.2s	remaining: 1m 45s
# 126:	learn: 0.0019951	total: 15.3s	remaining: 1m 45s
# 127:	learn: 0.0019950	total: 15.4s	remaining: 1m 45s
# 128:	learn: 0.0019949	total: 15.6s	remaining: 1m 45s
# 129:	learn: 0.0019948	total: 15.7s	remaining: 1m 45s
# 130:	learn: 0.0019947	total: 15.8s	remaining: 1m 45s
# 131:	learn: 0.0019946	total: 16s	remaining: 1m 45s
# 132:	learn: 0.0019946	total: 16.1s	remaining: 1m 45s
# 133:	learn: 0.0019945	total: 16.2s	remaining: 1m 44s
# 134:	learn: 0.0019944	total: 16.4s	remaining: 1m 44s
# 135:	learn: 0.0019943	total: 16.5s	remaining: 1m 44s
# 136:	learn: 0.0019942	total: 16.6s	remaining: 1m 44s
# 137:	learn: 0.0019941	total: 16.7s	remaining: 1m 44s
# 138:	learn: 0.0019941	total: 16.8s	remaining: 1m 44s
# 139:	learn: 0.0019940	total: 17s	remaining: 1m 44s
# 140:	learn: 0.0019939	total: 17.1s	remaining: 1m 44s
# 141:	learn: 0.0019937	total: 17.2s	remaining: 1m 44s
# 142:	learn: 0.0019936	total: 17.4s	remaining: 1m 44s
# 143:	learn: 0.0019936	total: 17.5s	remaining: 1m 43s
# 144:	learn: 0.0019935	total: 17.6s	remaining: 1m 43s
# 145:	learn: 0.0019934	total: 17.7s	remaining: 1m 43s
# 146:	learn: 0.0019934	total: 17.9s	remaining: 1m 43s
# 147:	learn: 0.0019933	total: 18s	remaining: 1m 43s
# 148:	learn: 0.0019932	total: 18.1s	remaining: 1m 43s
# 149:	learn: 0.0019931	total: 18.2s	remaining: 1m 43s
# 150:	learn: 0.0019929	total: 18.4s	remaining: 1m 43s
# 151:	learn: 0.0019929	total: 18.5s	remaining: 1m 43s
# 152:	learn: 0.0019928	total: 18.6s	remaining: 1m 42s
# 153:	learn: 0.0019928	total: 18.7s	remaining: 1m 42s
# 154:	learn: 0.0019927	total: 18.9s	remaining: 1m 42s
# 155:	learn: 0.0019926	total: 19s	remaining: 1m 42s
# 156:	learn: 0.0019926	total: 19.1s	remaining: 1m 42s
# 157:	learn: 0.0019925	total: 19.2s	remaining: 1m 42s
# 158:	learn: 0.0019924	total: 19.4s	remaining: 1m 42s
# 159:	learn: 0.0019924	total: 19.5s	remaining: 1m 42s
# 160:	learn: 0.0019922	total: 19.6s	remaining: 1m 42s
# 161:	learn: 0.0019922	total: 19.7s	remaining: 1m 42s
# 162:	learn: 0.0019921	total: 19.8s	remaining: 1m 41s
# 163:	learn: 0.0019921	total: 20s	remaining: 1m 41s
# 164:	learn: 0.0019918	total: 20.1s	remaining: 1m 41s
# 165:	learn: 0.0019918	total: 20.2s	remaining: 1m 41s
# 166:	learn: 0.0019917	total: 20.3s	remaining: 1m 41s
# 167:	learn: 0.0019916	total: 20.4s	remaining: 1m 41s
# 168:	learn: 0.0019915	total: 20.5s	remaining: 1m 41s
# 169:	learn: 0.0019915	total: 20.6s	remaining: 1m 40s
# 170:	learn: 0.0019914	total: 20.8s	remaining: 1m 40s
# 171:	learn: 0.0019913	total: 20.9s	remaining: 1m 40s
# 172:	learn: 0.0019913	total: 21s	remaining: 1m 40s
# 173:	learn: 0.0019912	total: 21.1s	remaining: 1m 40s
# 174:	learn: 0.0019912	total: 21.3s	remaining: 1m 40s
# 175:	learn: 0.0019911	total: 21.4s	remaining: 1m 40s
# 176:	learn: 0.0019911	total: 21.5s	remaining: 1m 39s
# 177:	learn: 0.0019910	total: 21.6s	remaining: 1m 39s
# 178:	learn: 0.0019909	total: 21.7s	remaining: 1m 39s
# 179:	learn: 0.0019908	total: 21.8s	remaining: 1m 39s
# 180:	learn: 0.0019907	total: 22s	remaining: 1m 39s
# 181:	learn: 0.0019907	total: 22.1s	remaining: 1m 39s
# 182:	learn: 0.0019906	total: 22.2s	remaining: 1m 39s
# 183:	learn: 0.0019906	total: 22.3s	remaining: 1m 38s
# 184:	learn: 0.0019906	total: 22.4s	remaining: 1m 38s
# 185:	learn: 0.0019905	total: 22.5s	remaining: 1m 38s
# 186:	learn: 0.0019904	total: 22.6s	remaining: 1m 38s
# 187:	learn: 0.0019904	total: 22.8s	remaining: 1m 38s
# 188:	learn: 0.0019903	total: 22.9s	remaining: 1m 38s
# 189:	learn: 0.0019903	total: 23s	remaining: 1m 37s
# 190:	learn: 0.0019902	total: 23.1s	remaining: 1m 37s
# 191:	learn: 0.0019901	total: 23.2s	remaining: 1m 37s
# 192:	learn: 0.0019900	total: 23.4s	remaining: 1m 37s
# 193:	learn: 0.0019900	total: 23.5s	remaining: 1m 37s
# 194:	learn: 0.0019899	total: 23.6s	remaining: 1m 37s
# 195:	learn: 0.0019899	total: 23.7s	remaining: 1m 37s
# 196:	learn: 0.0019898	total: 23.8s	remaining: 1m 37s
# 197:	learn: 0.0019898	total: 23.9s	remaining: 1m 37s
# 198:	learn: 0.0019897	total: 24.1s	remaining: 1m 36s
# 199:	learn: 0.0019897	total: 24.2s	remaining: 1m 36s
# 200:	learn: 0.0019896	total: 24.3s	remaining: 1m 36s
# 201:	learn: 0.0019896	total: 24.5s	remaining: 1m 36s
# 202:	learn: 0.0019895	total: 24.6s	remaining: 1m 36s
# 203:	learn: 0.0019895	total: 24.8s	remaining: 1m 36s
# 204:	learn: 0.0019894	total: 24.9s	remaining: 1m 36s
# 205:	learn: 0.0019894	total: 25s	remaining: 1m 36s
# 206:	learn: 0.0019893	total: 25.1s	remaining: 1m 36s
# 207:	learn: 0.0019893	total: 25.2s	remaining: 1m 36s
# 208:	learn: 0.0019892	total: 25.4s	remaining: 1m 35s
# 209:	learn: 0.0019891	total: 25.5s	remaining: 1m 35s
# 210:	learn: 0.0019891	total: 25.6s	remaining: 1m 35s
# 211:	learn: 0.0019890	total: 25.7s	remaining: 1m 35s
# 212:	learn: 0.0019890	total: 25.8s	remaining: 1m 35s
# 213:	learn: 0.0019890	total: 25.9s	remaining: 1m 35s
# 214:	learn: 0.0019889	total: 26.1s	remaining: 1m 35s
# 215:	learn: 0.0019889	total: 26.2s	remaining: 1m 35s
# 216:	learn: 0.0019888	total: 26.3s	remaining: 1m 34s
# 217:	learn: 0.0019888	total: 26.4s	remaining: 1m 34s
# 218:	learn: 0.0019887	total: 26.6s	remaining: 1m 34s
# 219:	learn: 0.0019885	total: 26.7s	remaining: 1m 34s
# 220:	learn: 0.0019885	total: 26.8s	remaining: 1m 34s
# 221:	learn: 0.0019885	total: 26.9s	remaining: 1m 34s
# 222:	learn: 0.0019884	total: 27.1s	remaining: 1m 34s
# 223:	learn: 0.0019883	total: 27.2s	remaining: 1m 34s
# 224:	learn: 0.0019882	total: 27.3s	remaining: 1m 34s
# 225:	learn: 0.0019881	total: 27.5s	remaining: 1m 34s
# 226:	learn: 0.0019881	total: 27.6s	remaining: 1m 33s
# 227:	learn: 0.0019880	total: 27.7s	remaining: 1m 33s
# 228:	learn: 0.0019879	total: 27.8s	remaining: 1m 33s
# 229:	learn: 0.0019879	total: 28s	remaining: 1m 33s
# 230:	learn: 0.0019878	total: 28.1s	remaining: 1m 33s
# 231:	learn: 0.0019878	total: 28.2s	remaining: 1m 33s
# 232:	learn: 0.0019877	total: 28.3s	remaining: 1m 33s
# 233:	learn: 0.0019877	total: 28.4s	remaining: 1m 33s
# 234:	learn: 0.0019876	total: 28.6s	remaining: 1m 33s
# 235:	learn: 0.0019875	total: 28.7s	remaining: 1m 32s
# 236:	learn: 0.0019874	total: 28.8s	remaining: 1m 32s
# 237:	learn: 0.0019874	total: 28.9s	remaining: 1m 32s
# 238:	learn: 0.0019873	total: 29s	remaining: 1m 32s
# 239:	learn: 0.0019873	total: 29.2s	remaining: 1m 32s
# 240:	learn: 0.0019872	total: 29.3s	remaining: 1m 32s
# 241:	learn: 0.0019871	total: 29.4s	remaining: 1m 32s
# 242:	learn: 0.0019870	total: 29.5s	remaining: 1m 32s
# 243:	learn: 0.0019870	total: 29.7s	remaining: 1m 31s
# 244:	learn: 0.0019870	total: 29.8s	remaining: 1m 31s
# 245:	learn: 0.0019869	total: 29.9s	remaining: 1m 31s
# 246:	learn: 0.0019868	total: 30.1s	remaining: 1m 31s
# 247:	learn: 0.0019867	total: 30.2s	remaining: 1m 31s
# 248:	learn: 0.0019866	total: 30.3s	remaining: 1m 31s
# 249:	learn: 0.0019865	total: 30.5s	remaining: 1m 31s
# 250:	learn: 0.0019865	total: 30.6s	remaining: 1m 31s
# 251:	learn: 0.0019864	total: 30.7s	remaining: 1m 31s
# 252:	learn: 0.0019863	total: 30.8s	remaining: 1m 31s
# 253:	learn: 0.0019862	total: 31s	remaining: 1m 30s
# 254:	learn: 0.0019862	total: 31.1s	remaining: 1m 30s
# 255:	learn: 0.0019861	total: 31.2s	remaining: 1m 30s
# 256:	learn: 0.0019861	total: 31.4s	remaining: 1m 30s
# 257:	learn: 0.0019860	total: 31.5s	remaining: 1m 30s
# 258:	learn: 0.0019860	total: 31.6s	remaining: 1m 30s
# 259:	learn: 0.0019859	total: 31.7s	remaining: 1m 30s
# 260:	learn: 0.0019859	total: 31.8s	remaining: 1m 30s
# 261:	learn: 0.0019858	total: 32s	remaining: 1m 30s
# 262:	learn: 0.0019858	total: 32.1s	remaining: 1m 29s
# 263:	learn: 0.0019857	total: 32.2s	remaining: 1m 29s
# 264:	learn: 0.0019857	total: 32.3s	remaining: 1m 29s
# 265:	learn: 0.0019856	total: 32.5s	remaining: 1m 29s
# 266:	learn: 0.0019854	total: 32.6s	remaining: 1m 29s
# 267:	learn: 0.0019854	total: 32.7s	remaining: 1m 29s
# 268:	learn: 0.0019853	total: 32.9s	remaining: 1m 29s
# 269:	learn: 0.0019853	total: 33s	remaining: 1m 29s
# 270:	learn: 0.0019852	total: 33.1s	remaining: 1m 29s
# 271:	learn: 0.0019851	total: 33.2s	remaining: 1m 28s
# 272:	learn: 0.0019850	total: 33.4s	remaining: 1m 28s
# 273:	learn: 0.0019850	total: 33.5s	remaining: 1m 28s
# 274:	learn: 0.0019849	total: 33.6s	remaining: 1m 28s
# 275:	learn: 0.0019849	total: 33.7s	remaining: 1m 28s
# 276:	learn: 0.0019849	total: 33.9s	remaining: 1m 28s
# 277:	learn: 0.0019848	total: 34s	remaining: 1m 28s
# 278:	learn: 0.0019848	total: 34.1s	remaining: 1m 28s
# 279:	learn: 0.0019848	total: 34.2s	remaining: 1m 27s
# 280:	learn: 0.0019847	total: 34.3s	remaining: 1m 27s
# 281:	learn: 0.0019846	total: 34.5s	remaining: 1m 27s
# 282:	learn: 0.0019846	total: 34.6s	remaining: 1m 27s
# 283:	learn: 0.0019845	total: 34.7s	remaining: 1m 27s
# 284:	learn: 0.0019845	total: 34.8s	remaining: 1m 27s
# 285:	learn: 0.0019845	total: 34.9s	remaining: 1m 27s
# 286:	learn: 0.0019844	total: 35.1s	remaining: 1m 27s
# 287:	learn: 0.0019844	total: 35.2s	remaining: 1m 27s
# 288:	learn: 0.0019843	total: 35.3s	remaining: 1m 26s
# 289:	learn: 0.0019842	total: 35.4s	remaining: 1m 26s
# 290:	learn: 0.0019842	total: 35.6s	remaining: 1m 26s
# 291:	learn: 0.0019841	total: 35.7s	remaining: 1m 26s
# 292:	learn: 0.0019841	total: 35.8s	remaining: 1m 26s
# 293:	learn: 0.0019841	total: 35.9s	remaining: 1m 26s
# 294:	learn: 0.0019840	total: 36.1s	remaining: 1m 26s
# 295:	learn: 0.0019839	total: 36.2s	remaining: 1m 26s
# 296:	learn: 0.0019839	total: 36.4s	remaining: 1m 26s
# 297:	learn: 0.0019839	total: 36.5s	remaining: 1m 25s
# 298:	learn: 0.0019838	total: 36.6s	remaining: 1m 25s
# 299:	learn: 0.0019838	total: 36.7s	remaining: 1m 25s
# 300:	learn: 0.0019837	total: 36.9s	remaining: 1m 25s
# 301:	learn: 0.0019837	total: 37s	remaining: 1m 25s
# 302:	learn: 0.0019836	total: 37.2s	remaining: 1m 25s
# 303:	learn: 0.0019836	total: 37.3s	remaining: 1m 25s
# 304:	learn: 0.0019835	total: 37.4s	remaining: 1m 25s
# 305:	learn: 0.0019835	total: 37.6s	remaining: 1m 25s
# 306:	learn: 0.0019835	total: 37.7s	remaining: 1m 25s
# 307:	learn: 0.0019834	total: 37.9s	remaining: 1m 25s
# 308:	learn: 0.0019833	total: 38s	remaining: 1m 24s
# 309:	learn: 0.0019832	total: 38.1s	remaining: 1m 24s
# 310:	learn: 0.0019832	total: 38.3s	remaining: 1m 24s
# 311:	learn: 0.0019831	total: 38.4s	remaining: 1m 24s
# 312:	learn: 0.0019830	total: 38.6s	remaining: 1m 24s
# 313:	learn: 0.0019829	total: 38.7s	remaining: 1m 24s
# 314:	learn: 0.0019829	total: 38.8s	remaining: 1m 24s
# 315:	learn: 0.0019829	total: 38.9s	remaining: 1m 24s
# 316:	learn: 0.0019828	total: 39.1s	remaining: 1m 24s
# 317:	learn: 0.0019828	total: 39.2s	remaining: 1m 24s
# 318:	learn: 0.0019827	total: 39.3s	remaining: 1m 23s
# 319:	learn: 0.0019826	total: 39.4s	remaining: 1m 23s
# 320:	learn: 0.0019826	total: 39.6s	remaining: 1m 23s
# 321:	learn: 0.0019825	total: 39.7s	remaining: 1m 23s
# 322:	learn: 0.0019825	total: 39.8s	remaining: 1m 23s
# 323:	learn: 0.0019824	total: 39.9s	remaining: 1m 23s
# 324:	learn: 0.0019824	total: 40.1s	remaining: 1m 23s
# 325:	learn: 0.0019822	total: 40.2s	remaining: 1m 23s
# 326:	learn: 0.0019822	total: 40.3s	remaining: 1m 22s
# 327:	learn: 0.0019822	total: 40.4s	remaining: 1m 22s
# 328:	learn: 0.0019821	total: 40.6s	remaining: 1m 22s
# 329:	learn: 0.0019821	total: 40.7s	remaining: 1m 22s
# 330:	learn: 0.0019820	total: 40.8s	remaining: 1m 22s
# 331:	learn: 0.0019820	total: 40.9s	remaining: 1m 22s
# 332:	learn: 0.0019819	total: 41s	remaining: 1m 22s
# 333:	learn: 0.0019819	total: 41.1s	remaining: 1m 22s
# 334:	learn: 0.0019818	total: 41.3s	remaining: 1m 21s
# 335:	learn: 0.0019818	total: 41.4s	remaining: 1m 21s
# 336:	learn: 0.0019817	total: 41.5s	remaining: 1m 21s
# 337:	learn: 0.0019817	total: 41.6s	remaining: 1m 21s
# 338:	learn: 0.0019817	total: 41.8s	remaining: 1m 21s
# 339:	learn: 0.0019816	total: 41.9s	remaining: 1m 21s
# 340:	learn: 0.0019816	total: 42s	remaining: 1m 21s
# 341:	learn: 0.0019816	total: 42.1s	remaining: 1m 20s
# 342:	learn: 0.0019815	total: 42.2s	remaining: 1m 20s
# 343:	learn: 0.0019814	total: 42.3s	remaining: 1m 20s
# 344:	learn: 0.0019814	total: 42.5s	remaining: 1m 20s
# 345:	learn: 0.0019813	total: 42.6s	remaining: 1m 20s
# 346:	learn: 0.0019812	total: 42.7s	remaining: 1m 20s
# 347:	learn: 0.0019812	total: 42.9s	remaining: 1m 20s
# 348:	learn: 0.0019812	total: 43s	remaining: 1m 20s
# 349:	learn: 0.0019812	total: 43.1s	remaining: 1m 20s
# 350:	learn: 0.0019811	total: 43.2s	remaining: 1m 19s
# 351:	learn: 0.0019811	total: 43.3s	remaining: 1m 19s
# 352:	learn: 0.0019811	total: 43.4s	remaining: 1m 19s
# 353:	learn: 0.0019810	total: 43.6s	remaining: 1m 19s
# 354:	learn: 0.0019810	total: 43.7s	remaining: 1m 19s
# 355:	learn: 0.0019810	total: 43.8s	remaining: 1m 19s
# 356:	learn: 0.0019810	total: 43.9s	remaining: 1m 19s
# 357:	learn: 0.0019809	total: 44s	remaining: 1m 18s
# 358:	learn: 0.0019809	total: 44.2s	remaining: 1m 18s
# 359:	learn: 0.0019808	total: 44.3s	remaining: 1m 18s
# 360:	learn: 0.0019808	total: 44.4s	remaining: 1m 18s
# 361:	learn: 0.0019807	total: 44.6s	remaining: 1m 18s
# 362:	learn: 0.0019807	total: 44.7s	remaining: 1m 18s
# 363:	learn: 0.0019806	total: 44.8s	remaining: 1m 18s
# 364:	learn: 0.0019806	total: 44.9s	remaining: 1m 18s
# 365:	learn: 0.0019806	total: 45s	remaining: 1m 18s
# 366:	learn: 0.0019805	total: 45.1s	remaining: 1m 17s
# 367:	learn: 0.0019804	total: 45.3s	remaining: 1m 17s
# 368:	learn: 0.0019804	total: 45.4s	remaining: 1m 17s
# 369:	learn: 0.0019803	total: 45.5s	remaining: 1m 17s
# 370:	learn: 0.0019803	total: 45.6s	remaining: 1m 17s
# 371:	learn: 0.0019803	total: 45.8s	remaining: 1m 17s
# 372:	learn: 0.0019802	total: 45.9s	remaining: 1m 17s
# 373:	learn: 0.0019802	total: 46s	remaining: 1m 17s
# 374:	learn: 0.0019801	total: 46.1s	remaining: 1m 16s
# 375:	learn: 0.0019801	total: 46.2s	remaining: 1m 16s
# 376:	learn: 0.0019801	total: 46.4s	remaining: 1m 16s
# 377:	learn: 0.0019801	total: 46.5s	remaining: 1m 16s
# 378:	learn: 0.0019800	total: 46.6s	remaining: 1m 16s
# 379:	learn: 0.0019800	total: 46.7s	remaining: 1m 16s
# 380:	learn: 0.0019800	total: 46.9s	remaining: 1m 16s
# 381:	learn: 0.0019800	total: 47s	remaining: 1m 16s
# 382:	learn: 0.0019799	total: 47.1s	remaining: 1m 15s
# 383:	learn: 0.0019799	total: 47.2s	remaining: 1m 15s
# 384:	learn: 0.0019798	total: 47.4s	remaining: 1m 15s
# 385:	learn: 0.0019797	total: 47.5s	remaining: 1m 15s
# 386:	learn: 0.0019797	total: 47.6s	remaining: 1m 15s
# 387:	learn: 0.0019796	total: 47.7s	remaining: 1m 15s
# 388:	learn: 0.0019796	total: 47.9s	remaining: 1m 15s
# 389:	learn: 0.0019795	total: 48s	remaining: 1m 15s
# 390:	learn: 0.0019795	total: 48.1s	remaining: 1m 14s
# 391:	learn: 0.0019795	total: 48.3s	remaining: 1m 14s
# 392:	learn: 0.0019794	total: 48.4s	remaining: 1m 14s
# 393:	learn: 0.0019794	total: 48.5s	remaining: 1m 14s
# 394:	learn: 0.0019794	total: 48.7s	remaining: 1m 14s
# 395:	learn: 0.0019793	total: 48.8s	remaining: 1m 14s
# 396:	learn: 0.0019792	total: 48.9s	remaining: 1m 14s
# 397:	learn: 0.0019792	total: 49.1s	remaining: 1m 14s
# 398:	learn: 0.0019791	total: 49.2s	remaining: 1m 14s
# 399:	learn: 0.0019790	total: 49.3s	remaining: 1m 13s
# 400:	learn: 0.0019790	total: 49.5s	remaining: 1m 13s
# 401:	learn: 0.0019789	total: 49.6s	remaining: 1m 13s
# 402:	learn: 0.0019788	total: 49.7s	remaining: 1m 13s
# 403:	learn: 0.0019788	total: 49.9s	remaining: 1m 13s
# 404:	learn: 0.0019787	total: 50s	remaining: 1m 13s
# 405:	learn: 0.0019787	total: 50.1s	remaining: 1m 13s
# 406:	learn: 0.0019786	total: 50.2s	remaining: 1m 13s
# 407:	learn: 0.0019786	total: 50.4s	remaining: 1m 13s
# 408:	learn: 0.0019786	total: 50.5s	remaining: 1m 12s
# 409:	learn: 0.0019785	total: 50.6s	remaining: 1m 12s
# 410:	learn: 0.0019785	total: 50.8s	remaining: 1m 12s
# 411:	learn: 0.0019785	total: 50.9s	remaining: 1m 12s
# 412:	learn: 0.0019784	total: 51s	remaining: 1m 12s
# 413:	learn: 0.0019784	total: 51.2s	remaining: 1m 12s
# 414:	learn: 0.0019783	total: 51.3s	remaining: 1m 12s
# 415:	learn: 0.0019782	total: 51.4s	remaining: 1m 12s
# 416:	learn: 0.0019782	total: 51.6s	remaining: 1m 12s
# 417:	learn: 0.0019781	total: 51.7s	remaining: 1m 11s
# 418:	learn: 0.0019781	total: 51.8s	remaining: 1m 11s
# 419:	learn: 0.0019780	total: 52s	remaining: 1m 11s
# 420:	learn: 0.0019780	total: 52.2s	remaining: 1m 11s
# 421:	learn: 0.0019779	total: 52.3s	remaining: 1m 11s
# 422:	learn: 0.0019779	total: 52.4s	remaining: 1m 11s
# 423:	learn: 0.0019778	total: 52.5s	remaining: 1m 11s
# 424:	learn: 0.0019778	total: 52.6s	remaining: 1m 11s
# 425:	learn: 0.0019778	total: 52.8s	remaining: 1m 11s
# 426:	learn: 0.0019778	total: 52.9s	remaining: 1m 11s
# 427:	learn: 0.0019777	total: 53.1s	remaining: 1m 10s
# 428:	learn: 0.0019776	total: 53.2s	remaining: 1m 10s
# 429:	learn: 0.0019776	total: 53.3s	remaining: 1m 10s
# 430:	learn: 0.0019776	total: 53.5s	remaining: 1m 10s
# 431:	learn: 0.0019775	total: 53.6s	remaining: 1m 10s
# 432:	learn: 0.0019775	total: 53.7s	remaining: 1m 10s
# 433:	learn: 0.0019774	total: 53.9s	remaining: 1m 10s
# 434:	learn: 0.0019774	total: 54.1s	remaining: 1m 10s
# 435:	learn: 0.0019773	total: 54.2s	remaining: 1m 10s
# 436:	learn: 0.0019773	total: 54.3s	remaining: 1m 9s
# 437:	learn: 0.0019773	total: 54.5s	remaining: 1m 9s
# 438:	learn: 0.0019773	total: 54.6s	remaining: 1m 9s
# 439:	learn: 0.0019772	total: 54.7s	remaining: 1m 9s
# 440:	learn: 0.0019771	total: 54.9s	remaining: 1m 9s
# 441:	learn: 0.0019771	total: 55s	remaining: 1m 9s
# 442:	learn: 0.0019771	total: 55.1s	remaining: 1m 9s
# 443:	learn: 0.0019770	total: 55.2s	remaining: 1m 9s
# 444:	learn: 0.0019770	total: 55.4s	remaining: 1m 9s
# 445:	learn: 0.0019770	total: 55.5s	remaining: 1m 8s
# 446:	learn: 0.0019768	total: 55.6s	remaining: 1m 8s
# 447:	learn: 0.0019768	total: 55.7s	remaining: 1m 8s
# 448:	learn: 0.0019768	total: 55.9s	remaining: 1m 8s
# 449:	learn: 0.0019767	total: 56s	remaining: 1m 8s
# 450:	learn: 0.0019767	total: 56.3s	remaining: 1m 8s
# 451:	learn: 0.0019766	total: 56.5s	remaining: 1m 8s
# 452:	learn: 0.0019766	total: 56.8s	remaining: 1m 8s
# 453:	learn: 0.0019766	total: 57s	remaining: 1m 8s
# 454:	learn: 0.0019766	total: 57.2s	remaining: 1m 8s
# 455:	learn: 0.0019765	total: 57.5s	remaining: 1m 8s
# 456:	learn: 0.0019765	total: 57.7s	remaining: 1m 8s
# 457:	learn: 0.0019765	total: 57.9s	remaining: 1m 8s
# 458:	learn: 0.0019765	total: 58.1s	remaining: 1m 8s
# 459:	learn: 0.0019764	total: 58.4s	remaining: 1m 8s
# 460:	learn: 0.0019763	total: 58.6s	remaining: 1m 8s
# 461:	learn: 0.0019763	total: 58.8s	remaining: 1m 8s
# 462:	learn: 0.0019762	total: 59.1s	remaining: 1m 8s
# 463:	learn: 0.0019761	total: 59.4s	remaining: 1m 8s
# 464:	learn: 0.0019761	total: 59.6s	remaining: 1m 8s
# 465:	learn: 0.0019761	total: 59.8s	remaining: 1m 8s
# 466:	learn: 0.0019761	total: 1m	remaining: 1m 8s
# 467:	learn: 0.0019760	total: 1m	remaining: 1m 8s
# 468:	learn: 0.0019760	total: 1m	remaining: 1m 8s
# 469:	learn: 0.0019759	total: 1m	remaining: 1m 8s
# 470:	learn: 0.0019759	total: 1m	remaining: 1m 8s
# 471:	learn: 0.0019758	total: 1m 1s	remaining: 1m 8s
# 472:	learn: 0.0019758	total: 1m 1s	remaining: 1m 8s
# 473:	learn: 0.0019758	total: 1m 1s	remaining: 1m 8s
# 474:	learn: 0.0019758	total: 1m 1s	remaining: 1m 8s
# 475:	learn: 0.0019758	total: 1m 1s	remaining: 1m 8s
# 476:	learn: 0.0019757	total: 1m 2s	remaining: 1m 8s
# 477:	learn: 0.0019756	total: 1m 2s	remaining: 1m 8s
# 478:	learn: 0.0019756	total: 1m 2s	remaining: 1m 8s
# 479:	learn: 0.0019756	total: 1m 2s	remaining: 1m 8s
# 480:	learn: 0.0019755	total: 1m 3s	remaining: 1m 8s
# 481:	learn: 0.0019755	total: 1m 3s	remaining: 1m 7s
# 482:	learn: 0.0019755	total: 1m 3s	remaining: 1m 7s
# 483:	learn: 0.0019754	total: 1m 3s	remaining: 1m 7s
# 484:	learn: 0.0019754	total: 1m 3s	remaining: 1m 7s
# 485:	learn: 0.0019753	total: 1m 4s	remaining: 1m 7s
# 486:	learn: 0.0019753	total: 1m 4s	remaining: 1m 7s
# 487:	learn: 0.0019752	total: 1m 4s	remaining: 1m 7s
# 488:	learn: 0.0019752	total: 1m 4s	remaining: 1m 7s
# 489:	learn: 0.0019751	total: 1m 4s	remaining: 1m 7s
# 490:	learn: 0.0019751	total: 1m 5s	remaining: 1m 7s
# 491:	learn: 0.0019751	total: 1m 5s	remaining: 1m 7s
# 492:	learn: 0.0019749	total: 1m 5s	remaining: 1m 7s
# 493:	learn: 0.0019749	total: 1m 5s	remaining: 1m 7s
# 494:	learn: 0.0019748	total: 1m 5s	remaining: 1m 7s
# 495:	learn: 0.0019748	total: 1m 6s	remaining: 1m 7s
# 496:	learn: 0.0019747	total: 1m 6s	remaining: 1m 7s
# 497:	learn: 0.0019747	total: 1m 6s	remaining: 1m 7s
# 498:	learn: 0.0019747	total: 1m 6s	remaining: 1m 7s
# 499:	learn: 0.0019746	total: 1m 7s	remaining: 1m 7s
# 500:	learn: 0.0019746	total: 1m 7s	remaining: 1m 6s
# 501:	learn: 0.0019745	total: 1m 7s	remaining: 1m 6s
# 502:	learn: 0.0019745	total: 1m 7s	remaining: 1m 6s
# 503:	learn: 0.0019744	total: 1m 7s	remaining: 1m 6s
# 504:	learn: 0.0019744	total: 1m 8s	remaining: 1m 6s
# 505:	learn: 0.0019744	total: 1m 8s	remaining: 1m 6s
# 506:	learn: 0.0019743	total: 1m 8s	remaining: 1m 6s
# 507:	learn: 0.0019743	total: 1m 8s	remaining: 1m 6s
# 508:	learn: 0.0019743	total: 1m 8s	remaining: 1m 6s
# 509:	learn: 0.0019742	total: 1m 9s	remaining: 1m 6s
# 510:	learn: 0.0019742	total: 1m 9s	remaining: 1m 6s
# 511:	learn: 0.0019742	total: 1m 9s	remaining: 1m 6s
# 512:	learn: 0.0019741	total: 1m 9s	remaining: 1m 6s
# 513:	learn: 0.0019741	total: 1m 10s	remaining: 1m 6s
# 514:	learn: 0.0019741	total: 1m 10s	remaining: 1m 6s
# 515:	learn: 0.0019740	total: 1m 10s	remaining: 1m 6s
# 516:	learn: 0.0019740	total: 1m 10s	remaining: 1m 6s
# 517:	learn: 0.0019739	total: 1m 10s	remaining: 1m 5s
# 518:	learn: 0.0019738	total: 1m 11s	remaining: 1m 5s
# 519:	learn: 0.0019738	total: 1m 11s	remaining: 1m 5s
# 520:	learn: 0.0019738	total: 1m 11s	remaining: 1m 5s
# 521:	learn: 0.0019738	total: 1m 11s	remaining: 1m 5s
# 522:	learn: 0.0019737	total: 1m 11s	remaining: 1m 5s
# 523:	learn: 0.0019737	total: 1m 12s	remaining: 1m 5s
# 524:	learn: 0.0019737	total: 1m 12s	remaining: 1m 5s
# 525:	learn: 0.0019737	total: 1m 12s	remaining: 1m 5s
# 526:	learn: 0.0019736	total: 1m 12s	remaining: 1m 5s
# 527:	learn: 0.0019736	total: 1m 12s	remaining: 1m 5s
# 528:	learn: 0.0019735	total: 1m 13s	remaining: 1m 5s
# 529:	learn: 0.0019735	total: 1m 13s	remaining: 1m 5s
# 530:	learn: 0.0019734	total: 1m 13s	remaining: 1m 4s
# 531:	learn: 0.0019734	total: 1m 13s	remaining: 1m 4s
# 532:	learn: 0.0019734	total: 1m 13s	remaining: 1m 4s
# 533:	learn: 0.0019733	total: 1m 14s	remaining: 1m 4s
# 534:	learn: 0.0019733	total: 1m 14s	remaining: 1m 4s
# 535:	learn: 0.0019732	total: 1m 14s	remaining: 1m 4s
# 536:	learn: 0.0019732	total: 1m 14s	remaining: 1m 4s
# 537:	learn: 0.0019731	total: 1m 14s	remaining: 1m 4s
# 538:	learn: 0.0019731	total: 1m 15s	remaining: 1m 4s
# 539:	learn: 0.0019731	total: 1m 15s	remaining: 1m 4s
# 540:	learn: 0.0019731	total: 1m 15s	remaining: 1m 4s
# 541:	learn: 0.0019730	total: 1m 15s	remaining: 1m 3s
# 542:	learn: 0.0019730	total: 1m 15s	remaining: 1m 3s
# 543:	learn: 0.0019730	total: 1m 16s	remaining: 1m 3s
# 544:	learn: 0.0019729	total: 1m 16s	remaining: 1m 3s
# 545:	learn: 0.0019729	total: 1m 16s	remaining: 1m 3s
# 546:	learn: 0.0019728	total: 1m 16s	remaining: 1m 3s
# 547:	learn: 0.0019728	total: 1m 16s	remaining: 1m 3s
# 548:	learn: 0.0019728	total: 1m 17s	remaining: 1m 3s
# 549:	learn: 0.0019728	total: 1m 17s	remaining: 1m 3s
# 550:	learn: 0.0019728	total: 1m 17s	remaining: 1m 3s
# 551:	learn: 0.0019727	total: 1m 17s	remaining: 1m 3s
# 552:	learn: 0.0019727	total: 1m 17s	remaining: 1m 2s
# 553:	learn: 0.0019727	total: 1m 18s	remaining: 1m 2s
# 554:	learn: 0.0019726	total: 1m 18s	remaining: 1m 2s
# 555:	learn: 0.0019726	total: 1m 18s	remaining: 1m 2s
# 556:	learn: 0.0019726	total: 1m 18s	remaining: 1m 2s
# 557:	learn: 0.0019725	total: 1m 18s	remaining: 1m 2s
# 558:	learn: 0.0019725	total: 1m 19s	remaining: 1m 2s
# 559:	learn: 0.0019724	total: 1m 19s	remaining: 1m 2s
# 560:	learn: 0.0019724	total: 1m 19s	remaining: 1m 2s
# 561:	learn: 0.0019724	total: 1m 19s	remaining: 1m 2s
# 562:	learn: 0.0019724	total: 1m 19s	remaining: 1m 2s
# 563:	learn: 0.0019724	total: 1m 20s	remaining: 1m 1s
# 564:	learn: 0.0019723	total: 1m 20s	remaining: 1m 1s
# 565:	learn: 0.0019723	total: 1m 20s	remaining: 1m 1s
# 566:	learn: 0.0019723	total: 1m 20s	remaining: 1m 1s
# 567:	learn: 0.0019722	total: 1m 20s	remaining: 1m 1s
# 568:	learn: 0.0019722	total: 1m 21s	remaining: 1m 1s
# 569:	learn: 0.0019721	total: 1m 21s	remaining: 1m 1s
# 570:	learn: 0.0019721	total: 1m 21s	remaining: 1m 1s
# 571:	learn: 0.0019721	total: 1m 21s	remaining: 1m 1s
# 572:	learn: 0.0019720	total: 1m 21s	remaining: 1m 1s
# 573:	learn: 0.0019720	total: 1m 22s	remaining: 1m 1s
# 574:	learn: 0.0019720	total: 1m 22s	remaining: 1m
# 575:	learn: 0.0019720	total: 1m 22s	remaining: 1m
# 576:	learn: 0.0019719	total: 1m 22s	remaining: 1m
# 577:	learn: 0.0019719	total: 1m 23s	remaining: 1m
# 578:	learn: 0.0019718	total: 1m 23s	remaining: 1m
# 579:	learn: 0.0019718	total: 1m 23s	remaining: 1m
# 580:	learn: 0.0019718	total: 1m 23s	remaining: 1m
# 581:	learn: 0.0019717	total: 1m 23s	remaining: 1m
# 582:	learn: 0.0019717	total: 1m 24s	remaining: 1m
# 583:	learn: 0.0019716	total: 1m 24s	remaining: 1m
# 584:	learn: 0.0019716	total: 1m 24s	remaining: 59.9s
# 585:	learn: 0.0019716	total: 1m 24s	remaining: 59.8s
# 586:	learn: 0.0019716	total: 1m 24s	remaining: 59.7s
# 587:	learn: 0.0019715	total: 1m 25s	remaining: 59.6s
# 588:	learn: 0.0019715	total: 1m 25s	remaining: 59.5s
# 589:	learn: 0.0019715	total: 1m 25s	remaining: 59.4s
# 590:	learn: 0.0019715	total: 1m 25s	remaining: 59.3s
# 591:	learn: 0.0019714	total: 1m 25s	remaining: 59.2s
# 592:	learn: 0.0019714	total: 1m 26s	remaining: 59.1s
# 593:	learn: 0.0019714	total: 1m 26s	remaining: 59s
# 594:	learn: 0.0019713	total: 1m 26s	remaining: 58.9s
# 595:	learn: 0.0019713	total: 1m 26s	remaining: 58.7s
# 596:	learn: 0.0019713	total: 1m 26s	remaining: 58.6s
# 597:	learn: 0.0019713	total: 1m 27s	remaining: 58.5s
# 598:	learn: 0.0019711	total: 1m 27s	remaining: 58.4s
# 599:	learn: 0.0019711	total: 1m 27s	remaining: 58.3s
# 600:	learn: 0.0019711	total: 1m 27s	remaining: 58.2s
# 601:	learn: 0.0019710	total: 1m 27s	remaining: 58.1s
# 602:	learn: 0.0019710	total: 1m 28s	remaining: 58s
# 603:	learn: 0.0019710	total: 1m 28s	remaining: 57.9s
# 604:	learn: 0.0019709	total: 1m 28s	remaining: 57.8s
# 605:	learn: 0.0019709	total: 1m 28s	remaining: 57.7s
# 606:	learn: 0.0019709	total: 1m 28s	remaining: 57.6s
# 607:	learn: 0.0019709	total: 1m 29s	remaining: 57.5s
# 608:	learn: 0.0019708	total: 1m 29s	remaining: 57.3s
# 609:	learn: 0.0019708	total: 1m 29s	remaining: 57.2s
# 610:	learn: 0.0019708	total: 1m 29s	remaining: 57.1s
# 611:	learn: 0.0019708	total: 1m 29s	remaining: 57s
# 612:	learn: 0.0019707	total: 1m 30s	remaining: 56.9s
# 613:	learn: 0.0019707	total: 1m 30s	remaining: 56.8s
# 614:	learn: 0.0019707	total: 1m 30s	remaining: 56.8s
# 615:	learn: 0.0019707	total: 1m 30s	remaining: 56.6s
# 616:	learn: 0.0019706	total: 1m 31s	remaining: 56.5s
# 617:	learn: 0.0019706	total: 1m 31s	remaining: 56.4s
# 618:	learn: 0.0019706	total: 1m 31s	remaining: 56.3s
# 619:	learn: 0.0019705	total: 1m 31s	remaining: 56.1s
# 620:	learn: 0.0019705	total: 1m 31s	remaining: 56s
# 621:	learn: 0.0019705	total: 1m 31s	remaining: 55.9s
# 622:	learn: 0.0019704	total: 1m 32s	remaining: 55.8s
# 623:	learn: 0.0019704	total: 1m 32s	remaining: 55.7s
# 624:	learn: 0.0019704	total: 1m 32s	remaining: 55.5s
# 625:	learn: 0.0019703	total: 1m 32s	remaining: 55.4s
# 626:	learn: 0.0019703	total: 1m 32s	remaining: 55.3s
# 627:	learn: 0.0019703	total: 1m 33s	remaining: 55.2s
# 628:	learn: 0.0019702	total: 1m 33s	remaining: 55.1s
# 629:	learn: 0.0019702	total: 1m 33s	remaining: 55s
# 630:	learn: 0.0019702	total: 1m 33s	remaining: 54.8s
# 631:	learn: 0.0019702	total: 1m 33s	remaining: 54.7s
# 632:	learn: 0.0019701	total: 1m 34s	remaining: 54.6s
# 633:	learn: 0.0019701	total: 1m 34s	remaining: 54.5s
# 634:	learn: 0.0019701	total: 1m 34s	remaining: 54.4s
# 635:	learn: 0.0019700	total: 1m 34s	remaining: 54.2s
# 636:	learn: 0.0019700	total: 1m 35s	remaining: 54.2s
# 637:	learn: 0.0019700	total: 1m 35s	remaining: 54.1s
# 638:	learn: 0.0019700	total: 1m 35s	remaining: 54s
# 639:	learn: 0.0019700	total: 1m 35s	remaining: 53.8s
# 640:	learn: 0.0019699	total: 1m 35s	remaining: 53.7s
# 641:	learn: 0.0019699	total: 1m 36s	remaining: 53.6s
# 642:	learn: 0.0019698	total: 1m 36s	remaining: 53.5s
# 643:	learn: 0.0019698	total: 1m 36s	remaining: 53.3s
# 644:	learn: 0.0019698	total: 1m 36s	remaining: 53.2s
# 645:	learn: 0.0019698	total: 1m 36s	remaining: 53.1s
# 646:	learn: 0.0019697	total: 1m 37s	remaining: 53s
# 647:	learn: 0.0019697	total: 1m 37s	remaining: 52.9s
# 648:	learn: 0.0019697	total: 1m 37s	remaining: 52.7s
# 649:	learn: 0.0019697	total: 1m 37s	remaining: 52.6s
# 650:	learn: 0.0019696	total: 1m 37s	remaining: 52.5s
# 651:	learn: 0.0019696	total: 1m 38s	remaining: 52.4s
# 652:	learn: 0.0019696	total: 1m 38s	remaining: 52.3s
# 653:	learn: 0.0019696	total: 1m 38s	remaining: 52.1s
# 654:	learn: 0.0019695	total: 1m 38s	remaining: 52s
# 655:	learn: 0.0019695	total: 1m 38s	remaining: 51.9s
# 656:	learn: 0.0019695	total: 1m 39s	remaining: 51.8s
# 657:	learn: 0.0019694	total: 1m 39s	remaining: 51.6s
# 658:	learn: 0.0019694	total: 1m 39s	remaining: 51.5s
# 659:	learn: 0.0019694	total: 1m 39s	remaining: 51.4s
# 660:	learn: 0.0019693	total: 1m 39s	remaining: 51.3s
# 661:	learn: 0.0019693	total: 1m 40s	remaining: 51.1s
# 662:	learn: 0.0019692	total: 1m 40s	remaining: 51s
# 663:	learn: 0.0019692	total: 1m 40s	remaining: 50.9s
# 664:	learn: 0.0019692	total: 1m 40s	remaining: 50.7s
# 665:	learn: 0.0019691	total: 1m 40s	remaining: 50.6s
# 666:	learn: 0.0019691	total: 1m 41s	remaining: 50.5s
# 667:	learn: 0.0019691	total: 1m 41s	remaining: 50.4s
# 668:	learn: 0.0019691	total: 1m 41s	remaining: 50.3s
# 669:	learn: 0.0019690	total: 1m 41s	remaining: 50.1s
# 670:	learn: 0.0019690	total: 1m 41s	remaining: 50s
# 671:	learn: 0.0019689	total: 1m 42s	remaining: 49.9s
# 672:	learn: 0.0019689	total: 1m 42s	remaining: 49.8s
# 673:	learn: 0.0019689	total: 1m 42s	remaining: 49.6s
# 674:	learn: 0.0019688	total: 1m 42s	remaining: 49.5s
# 675:	learn: 0.0019688	total: 1m 42s	remaining: 49.4s
# 676:	learn: 0.0019687	total: 1m 43s	remaining: 49.2s
# 677:	learn: 0.0019687	total: 1m 43s	remaining: 49.1s
# 678:	learn: 0.0019687	total: 1m 43s	remaining: 49s
# 679:	learn: 0.0019687	total: 1m 43s	remaining: 48.9s
# 680:	learn: 0.0019686	total: 1m 44s	remaining: 48.8s
# 681:	learn: 0.0019686	total: 1m 44s	remaining: 48.6s
# 682:	learn: 0.0019685	total: 1m 44s	remaining: 48.5s
# 683:	learn: 0.0019685	total: 1m 44s	remaining: 48.4s
# 684:	learn: 0.0019685	total: 1m 44s	remaining: 48.3s
# 685:	learn: 0.0019685	total: 1m 45s	remaining: 48.1s
# 686:	learn: 0.0019684	total: 1m 45s	remaining: 48s
# 687:	learn: 0.0019684	total: 1m 45s	remaining: 47.9s
# 688:	learn: 0.0019684	total: 1m 45s	remaining: 47.8s
# 689:	learn: 0.0019683	total: 1m 46s	remaining: 47.6s
# 690:	learn: 0.0019683	total: 1m 46s	remaining: 47.5s
# 691:	learn: 0.0019683	total: 1m 46s	remaining: 47.4s
# 692:	learn: 0.0019682	total: 1m 46s	remaining: 47.2s
# 693:	learn: 0.0019682	total: 1m 46s	remaining: 47.1s
# 694:	learn: 0.0019682	total: 1m 47s	remaining: 47s
# 695:	learn: 0.0019681	total: 1m 47s	remaining: 46.9s
# 696:	learn: 0.0019681	total: 1m 47s	remaining: 46.7s
# 697:	learn: 0.0019681	total: 1m 47s	remaining: 46.6s
# 698:	learn: 0.0019681	total: 1m 47s	remaining: 46.5s
# 699:	learn: 0.0019681	total: 1m 48s	remaining: 46.3s
# 700:	learn: 0.0019681	total: 1m 48s	remaining: 46.2s
# 701:	learn: 0.0019680	total: 1m 48s	remaining: 46.1s
# 702:	learn: 0.0019680	total: 1m 48s	remaining: 46s
# 703:	learn: 0.0019679	total: 1m 49s	remaining: 45.8s
# 704:	learn: 0.0019679	total: 1m 49s	remaining: 45.7s
# 705:	learn: 0.0019679	total: 1m 49s	remaining: 45.6s
# 706:	learn: 0.0019678	total: 1m 49s	remaining: 45.4s
# 707:	learn: 0.0019678	total: 1m 49s	remaining: 45.3s
# 708:	learn: 0.0019677	total: 1m 50s	remaining: 45.2s
# 709:	learn: 0.0019677	total: 1m 50s	remaining: 45s
# 710:	learn: 0.0019676	total: 1m 50s	remaining: 44.9s
# 711:	learn: 0.0019676	total: 1m 50s	remaining: 44.8s
# 712:	learn: 0.0019676	total: 1m 50s	remaining: 44.6s
# 713:	learn: 0.0019675	total: 1m 51s	remaining: 44.5s
# 714:	learn: 0.0019675	total: 1m 51s	remaining: 44.3s
# 715:	learn: 0.0019674	total: 1m 51s	remaining: 44.2s
# 716:	learn: 0.0019674	total: 1m 51s	remaining: 44.1s
# 717:	learn: 0.0019674	total: 1m 51s	remaining: 43.9s
# 718:	learn: 0.0019674	total: 1m 52s	remaining: 43.8s
# 719:	learn: 0.0019673	total: 1m 52s	remaining: 43.7s
# 720:	learn: 0.0019673	total: 1m 52s	remaining: 43.5s
# 721:	learn: 0.0019672	total: 1m 52s	remaining: 43.4s
# 722:	learn: 0.0019672	total: 1m 52s	remaining: 43.3s
# 723:	learn: 0.0019672	total: 1m 53s	remaining: 43.1s
# 724:	learn: 0.0019671	total: 1m 53s	remaining: 43s
# 725:	learn: 0.0019671	total: 1m 53s	remaining: 42.8s
# 726:	learn: 0.0019671	total: 1m 53s	remaining: 42.7s
# 727:	learn: 0.0019670	total: 1m 54s	remaining: 42.6s
# 728:	learn: 0.0019670	total: 1m 54s	remaining: 42.5s
# 729:	learn: 0.0019670	total: 1m 54s	remaining: 42.3s
# 730:	learn: 0.0019670	total: 1m 54s	remaining: 42.2s
# 731:	learn: 0.0019669	total: 1m 54s	remaining: 42s
# 732:	learn: 0.0019669	total: 1m 55s	remaining: 41.9s
# 733:	learn: 0.0019669	total: 1m 55s	remaining: 41.8s
# 734:	learn: 0.0019669	total: 1m 55s	remaining: 41.6s
# 735:	learn: 0.0019669	total: 1m 55s	remaining: 41.5s
# 736:	learn: 0.0019668	total: 1m 55s	remaining: 41.4s
# 737:	learn: 0.0019668	total: 1m 56s	remaining: 41.2s
# 738:	learn: 0.0019668	total: 1m 56s	remaining: 41.1s
# 739:	learn: 0.0019668	total: 1m 56s	remaining: 40.9s
# 740:	learn: 0.0019667	total: 1m 56s	remaining: 40.8s
# 741:	learn: 0.0019667	total: 1m 56s	remaining: 40.6s
# 742:	learn: 0.0019667	total: 1m 57s	remaining: 40.5s
# 743:	learn: 0.0019667	total: 1m 57s	remaining: 40.4s
# 744:	learn: 0.0019666	total: 1m 57s	remaining: 40.2s
# 745:	learn: 0.0019666	total: 1m 57s	remaining: 40.1s
# 746:	learn: 0.0019666	total: 1m 57s	remaining: 39.9s
# 747:	learn: 0.0019665	total: 1m 58s	remaining: 39.8s
# 748:	learn: 0.0019665	total: 1m 58s	remaining: 39.6s
# 749:	learn: 0.0019665	total: 1m 58s	remaining: 39.5s
# 750:	learn: 0.0019665	total: 1m 58s	remaining: 39.3s
# 751:	learn: 0.0019664	total: 1m 58s	remaining: 39.2s
# 752:	learn: 0.0019664	total: 1m 59s	remaining: 39.1s
# 753:	learn: 0.0019664	total: 1m 59s	remaining: 38.9s
# 754:	learn: 0.0019664	total: 1m 59s	remaining: 38.8s
# 755:	learn: 0.0019663	total: 1m 59s	remaining: 38.6s
# 756:	learn: 0.0019663	total: 1m 59s	remaining: 38.5s
# 757:	learn: 0.0019662	total: 2m	remaining: 38.3s
# 758:	learn: 0.0019662	total: 2m	remaining: 38.2s
# 759:	learn: 0.0019662	total: 2m	remaining: 38s
# 760:	learn: 0.0019661	total: 2m	remaining: 37.9s
# 761:	learn: 0.0019661	total: 2m	remaining: 37.8s
# 762:	learn: 0.0019661	total: 2m 1s	remaining: 37.6s
# 763:	learn: 0.0019660	total: 2m 1s	remaining: 37.5s
# 764:	learn: 0.0019660	total: 2m 1s	remaining: 37.3s
# 765:	learn: 0.0019660	total: 2m 1s	remaining: 37.2s
# 766:	learn: 0.0019659	total: 2m 1s	remaining: 37s
# 767:	learn: 0.0019659	total: 2m 2s	remaining: 36.9s
# 768:	learn: 0.0019659	total: 2m 2s	remaining: 36.7s
# 769:	learn: 0.0019658	total: 2m 2s	remaining: 36.6s
# 770:	learn: 0.0019658	total: 2m 2s	remaining: 36.4s
# 771:	learn: 0.0019658	total: 2m 2s	remaining: 36.3s
# 772:	learn: 0.0019657	total: 2m 3s	remaining: 36.2s
# 773:	learn: 0.0019657	total: 2m 3s	remaining: 36s
# 774:	learn: 0.0019656	total: 2m 3s	remaining: 35.9s
# 775:	learn: 0.0019656	total: 2m 3s	remaining: 35.7s
# 776:	learn: 0.0019656	total: 2m 3s	remaining: 35.6s
# 777:	learn: 0.0019656	total: 2m 4s	remaining: 35.4s
# 778:	learn: 0.0019655	total: 2m 4s	remaining: 35.3s
# 779:	learn: 0.0019655	total: 2m 4s	remaining: 35.1s
# 780:	learn: 0.0019655	total: 2m 4s	remaining: 35s
# 781:	learn: 0.0019655	total: 2m 5s	remaining: 34.8s
# 782:	learn: 0.0019654	total: 2m 5s	remaining: 34.7s
# 783:	learn: 0.0019654	total: 2m 5s	remaining: 34.6s
# 784:	learn: 0.0019653	total: 2m 5s	remaining: 34.4s
# 785:	learn: 0.0019653	total: 2m 5s	remaining: 34.3s
# 786:	learn: 0.0019653	total: 2m 6s	remaining: 34.1s
# 787:	learn: 0.0019653	total: 2m 6s	remaining: 34s
# 788:	learn: 0.0019652	total: 2m 6s	remaining: 33.8s
# 789:	learn: 0.0019652	total: 2m 6s	remaining: 33.7s
# 790:	learn: 0.0019652	total: 2m 6s	remaining: 33.5s
# 791:	learn: 0.0019651	total: 2m 7s	remaining: 33.4s
# 792:	learn: 0.0019651	total: 2m 7s	remaining: 33.2s
# 793:	learn: 0.0019651	total: 2m 7s	remaining: 33.1s
# 794:	learn: 0.0019650	total: 2m 7s	remaining: 32.9s
# 795:	learn: 0.0019650	total: 2m 7s	remaining: 32.8s
# 796:	learn: 0.0019650	total: 2m 8s	remaining: 32.6s
# 797:	learn: 0.0019650	total: 2m 8s	remaining: 32.5s
# 798:	learn: 0.0019650	total: 2m 8s	remaining: 32.3s
# 799:	learn: 0.0019649	total: 2m 8s	remaining: 32.2s
# 800:	learn: 0.0019649	total: 2m 8s	remaining: 32s
# 801:	learn: 0.0019649	total: 2m 9s	remaining: 31.9s
# 802:	learn: 0.0019649	total: 2m 9s	remaining: 31.7s
# 803:	learn: 0.0019649	total: 2m 9s	remaining: 31.6s
# 804:	learn: 0.0019648	total: 2m 9s	remaining: 31.4s
# 805:	learn: 0.0019648	total: 2m 9s	remaining: 31.3s
# 806:	learn: 0.0019648	total: 2m 10s	remaining: 31.1s
# 807:	learn: 0.0019648	total: 2m 10s	remaining: 30.9s
# 808:	learn: 0.0019647	total: 2m 10s	remaining: 30.8s
# 809:	learn: 0.0019647	total: 2m 10s	remaining: 30.7s
# 810:	learn: 0.0019647	total: 2m 10s	remaining: 30.5s
# 811:	learn: 0.0019647	total: 2m 11s	remaining: 30.3s
# 812:	learn: 0.0019646	total: 2m 11s	remaining: 30.2s
# 813:	learn: 0.0019646	total: 2m 11s	remaining: 30s
# 814:	learn: 0.0019646	total: 2m 11s	remaining: 29.9s
# 815:	learn: 0.0019646	total: 2m 11s	remaining: 29.7s
# 816:	learn: 0.0019645	total: 2m 12s	remaining: 29.6s
# 817:	learn: 0.0019645	total: 2m 12s	remaining: 29.4s
# 818:	learn: 0.0019645	total: 2m 12s	remaining: 29.3s
# 819:	learn: 0.0019645	total: 2m 12s	remaining: 29.1s
# 820:	learn: 0.0019644	total: 2m 12s	remaining: 29s
# 821:	learn: 0.0019644	total: 2m 13s	remaining: 28.8s
# 822:	learn: 0.0019644	total: 2m 13s	remaining: 28.7s
# 823:	learn: 0.0019644	total: 2m 13s	remaining: 28.5s
# 824:	learn: 0.0019643	total: 2m 13s	remaining: 28.4s
# 825:	learn: 0.0019643	total: 2m 13s	remaining: 28.2s
# 826:	learn: 0.0019642	total: 2m 14s	remaining: 28.1s
# 827:	learn: 0.0019642	total: 2m 14s	remaining: 27.9s
# 828:	learn: 0.0019642	total: 2m 14s	remaining: 27.7s
# 829:	learn: 0.0019642	total: 2m 14s	remaining: 27.6s
# 830:	learn: 0.0019641	total: 2m 14s	remaining: 27.4s
# 831:	learn: 0.0019641	total: 2m 15s	remaining: 27.3s
# 832:	learn: 0.0019641	total: 2m 15s	remaining: 27.1s
# 833:	learn: 0.0019640	total: 2m 15s	remaining: 27s
# 834:	learn: 0.0019640	total: 2m 15s	remaining: 26.8s
# 835:	learn: 0.0019640	total: 2m 15s	remaining: 26.7s
# 836:	learn: 0.0019640	total: 2m 16s	remaining: 26.5s
# 837:	learn: 0.0019639	total: 2m 16s	remaining: 26.4s
# 838:	learn: 0.0019639	total: 2m 16s	remaining: 26.2s
# 839:	learn: 0.0019639	total: 2m 16s	remaining: 26s
# 840:	learn: 0.0019638	total: 2m 16s	remaining: 25.9s
# 841:	learn: 0.0019638	total: 2m 17s	remaining: 25.7s
# 842:	learn: 0.0019638	total: 2m 17s	remaining: 25.6s
# 843:	learn: 0.0019638	total: 2m 17s	remaining: 25.4s
# 844:	learn: 0.0019637	total: 2m 17s	remaining: 25.3s
# 845:	learn: 0.0019637	total: 2m 17s	remaining: 25.1s
# 846:	learn: 0.0019637	total: 2m 18s	remaining: 25s
# 847:	learn: 0.0019637	total: 2m 18s	remaining: 24.8s
# 848:	learn: 0.0019636	total: 2m 18s	remaining: 24.6s
# 849:	learn: 0.0019636	total: 2m 18s	remaining: 24.5s
# 850:	learn: 0.0019636	total: 2m 19s	remaining: 24.3s
# 851:	learn: 0.0019635	total: 2m 19s	remaining: 24.2s
# 852:	learn: 0.0019635	total: 2m 19s	remaining: 24s
# 853:	learn: 0.0019635	total: 2m 19s	remaining: 23.9s
# 854:	learn: 0.0019634	total: 2m 19s	remaining: 23.7s
# 855:	learn: 0.0019634	total: 2m 20s	remaining: 23.6s
# 856:	learn: 0.0019634	total: 2m 20s	remaining: 23.4s
# 857:	learn: 0.0019634	total: 2m 20s	remaining: 23.3s
# 858:	learn: 0.0019633	total: 2m 20s	remaining: 23.1s
# 859:	learn: 0.0019633	total: 2m 20s	remaining: 22.9s
# 860:	learn: 0.0019633	total: 2m 21s	remaining: 22.8s
# 861:	learn: 0.0019633	total: 2m 21s	remaining: 22.6s
# 862:	learn: 0.0019632	total: 2m 21s	remaining: 22.5s
# 863:	learn: 0.0019632	total: 2m 21s	remaining: 22.3s
# 864:	learn: 0.0019632	total: 2m 21s	remaining: 22.2s
# 865:	learn: 0.0019631	total: 2m 22s	remaining: 22s
# 866:	learn: 0.0019631	total: 2m 22s	remaining: 21.8s
# 867:	learn: 0.0019631	total: 2m 22s	remaining: 21.7s
# 868:	learn: 0.0019630	total: 2m 22s	remaining: 21.5s
# 869:	learn: 0.0019630	total: 2m 23s	remaining: 21.4s
# 870:	learn: 0.0019630	total: 2m 23s	remaining: 21.2s
# 871:	learn: 0.0019629	total: 2m 23s	remaining: 21.1s
# 872:	learn: 0.0019628	total: 2m 23s	remaining: 20.9s
# 873:	learn: 0.0019628	total: 2m 23s	remaining: 20.7s
# 874:	learn: 0.0019628	total: 2m 24s	remaining: 20.6s
# 875:	learn: 0.0019627	total: 2m 24s	remaining: 20.4s
# 876:	learn: 0.0019627	total: 2m 24s	remaining: 20.3s
# 877:	learn: 0.0019627	total: 2m 24s	remaining: 20.1s
# 878:	learn: 0.0019627	total: 2m 24s	remaining: 19.9s
# 879:	learn: 0.0019626	total: 2m 25s	remaining: 19.8s
# 880:	learn: 0.0019626	total: 2m 25s	remaining: 19.6s
# 881:	learn: 0.0019626	total: 2m 25s	remaining: 19.5s
# 882:	learn: 0.0019625	total: 2m 25s	remaining: 19.3s
# 883:	learn: 0.0019625	total: 2m 25s	remaining: 19.1s
# 884:	learn: 0.0019625	total: 2m 26s	remaining: 19s
# 885:	learn: 0.0019624	total: 2m 26s	remaining: 18.8s
# 886:	learn: 0.0019624	total: 2m 26s	remaining: 18.7s
# 887:	learn: 0.0019623	total: 2m 26s	remaining: 18.5s
# 888:	learn: 0.0019623	total: 2m 26s	remaining: 18.4s
# 889:	learn: 0.0019623	total: 2m 27s	remaining: 18.2s
# 890:	learn: 0.0019623	total: 2m 27s	remaining: 18s
# 891:	learn: 0.0019623	total: 2m 27s	remaining: 17.9s
# 892:	learn: 0.0019622	total: 2m 27s	remaining: 17.7s
# 893:	learn: 0.0019622	total: 2m 28s	remaining: 17.6s
# 894:	learn: 0.0019622	total: 2m 28s	remaining: 17.4s
# 895:	learn: 0.0019622	total: 2m 28s	remaining: 17.2s
# 896:	learn: 0.0019621	total: 2m 28s	remaining: 17.1s
# 897:	learn: 0.0019621	total: 2m 28s	remaining: 16.9s
# 898:	learn: 0.0019621	total: 2m 29s	remaining: 16.7s
# 899:	learn: 0.0019620	total: 2m 29s	remaining: 16.6s
# 900:	learn: 0.0019620	total: 2m 29s	remaining: 16.4s
# 901:	learn: 0.0019620	total: 2m 29s	remaining: 16.3s
# 902:	learn: 0.0019619	total: 2m 29s	remaining: 16.1s
# 903:	learn: 0.0019619	total: 2m 30s	remaining: 15.9s
# 904:	learn: 0.0019619	total: 2m 30s	remaining: 15.8s
# 905:	learn: 0.0019619	total: 2m 30s	remaining: 15.6s
# 906:	learn: 0.0019618	total: 2m 30s	remaining: 15.5s
# 907:	learn: 0.0019618	total: 2m 30s	remaining: 15.3s
# 908:	learn: 0.0019618	total: 2m 31s	remaining: 15.1s
# 909:	learn: 0.0019618	total: 2m 31s	remaining: 15s
# 910:	learn: 0.0019618	total: 2m 31s	remaining: 14.8s
# 911:	learn: 0.0019617	total: 2m 31s	remaining: 14.6s
# 912:	learn: 0.0019617	total: 2m 32s	remaining: 14.5s
# 913:	learn: 0.0019616	total: 2m 32s	remaining: 14.3s
# 914:	learn: 0.0019615	total: 2m 32s	remaining: 14.2s
# 915:	learn: 0.0019615	total: 2m 32s	remaining: 14s
# 916:	learn: 0.0019614	total: 2m 32s	remaining: 13.8s
# 917:	learn: 0.0019614	total: 2m 33s	remaining: 13.7s
# 918:	learn: 0.0019614	total: 2m 33s	remaining: 13.5s
# 919:	learn: 0.0019613	total: 2m 33s	remaining: 13.4s
# 920:	learn: 0.0019613	total: 2m 33s	remaining: 13.2s
# 921:	learn: 0.0019613	total: 2m 33s	remaining: 13s
# 922:	learn: 0.0019612	total: 2m 34s	remaining: 12.9s
# 923:	learn: 0.0019612	total: 2m 34s	remaining: 12.7s
# 924:	learn: 0.0019612	total: 2m 34s	remaining: 12.5s
# 925:	learn: 0.0019612	total: 2m 34s	remaining: 12.4s
# 926:	learn: 0.0019612	total: 2m 34s	remaining: 12.2s
# 927:	learn: 0.0019612	total: 2m 35s	remaining: 12s
# 928:	learn: 0.0019611	total: 2m 35s	remaining: 11.9s
# 929:	learn: 0.0019611	total: 2m 35s	remaining: 11.7s
# 930:	learn: 0.0019611	total: 2m 35s	remaining: 11.5s
# 931:	learn: 0.0019610	total: 2m 35s	remaining: 11.4s
# 932:	learn: 0.0019610	total: 2m 36s	remaining: 11.2s
# 933:	learn: 0.0019610	total: 2m 36s	remaining: 11s
# 934:	learn: 0.0019610	total: 2m 36s	remaining: 10.9s
# 935:	learn: 0.0019609	total: 2m 36s	remaining: 10.7s
# 936:	learn: 0.0019609	total: 2m 36s	remaining: 10.6s
# 937:	learn: 0.0019609	total: 2m 37s	remaining: 10.4s
# 938:	learn: 0.0019608	total: 2m 37s	remaining: 10.2s
# 939:	learn: 0.0019608	total: 2m 37s	remaining: 10.1s
# 940:	learn: 0.0019608	total: 2m 37s	remaining: 9.89s
# 941:	learn: 0.0019608	total: 2m 37s	remaining: 9.72s
# 942:	learn: 0.0019607	total: 2m 38s	remaining: 9.56s
# 943:	learn: 0.0019607	total: 2m 38s	remaining: 9.39s
# 944:	learn: 0.0019607	total: 2m 38s	remaining: 9.23s
# 945:	learn: 0.0019607	total: 2m 38s	remaining: 9.06s
# 946:	learn: 0.0019606	total: 2m 38s	remaining: 8.9s
# 947:	learn: 0.0019606	total: 2m 39s	remaining: 8.73s
# 948:	learn: 0.0019606	total: 2m 39s	remaining: 8.56s
# 949:	learn: 0.0019605	total: 2m 39s	remaining: 8.4s
# 950:	learn: 0.0019605	total: 2m 39s	remaining: 8.23s
# 951:	learn: 0.0019605	total: 2m 40s	remaining: 8.07s
# 952:	learn: 0.0019605	total: 2m 40s	remaining: 7.9s
# 953:	learn: 0.0019604	total: 2m 40s	remaining: 7.73s
# 954:	learn: 0.0019604	total: 2m 40s	remaining: 7.57s
# 955:	learn: 0.0019604	total: 2m 40s	remaining: 7.4s
# 956:	learn: 0.0019603	total: 2m 41s	remaining: 7.23s
# 957:	learn: 0.0019603	total: 2m 41s	remaining: 7.07s
# 958:	learn: 0.0019603	total: 2m 41s	remaining: 6.9s
# 959:	learn: 0.0019603	total: 2m 41s	remaining: 6.73s
# 960:	learn: 0.0019602	total: 2m 41s	remaining: 6.57s
# 961:	learn: 0.0019602	total: 2m 42s	remaining: 6.4s
# 962:	learn: 0.0019602	total: 2m 42s	remaining: 6.23s
# 963:	learn: 0.0019601	total: 2m 42s	remaining: 6.07s
# 964:	learn: 0.0019601	total: 2m 42s	remaining: 5.9s
# 965:	learn: 0.0019600	total: 2m 42s	remaining: 5.73s
# 966:	learn: 0.0019600	total: 2m 43s	remaining: 5.57s
# 967:	learn: 0.0019600	total: 2m 43s	remaining: 5.4s
# 968:	learn: 0.0019600	total: 2m 43s	remaining: 5.23s
# 969:	learn: 0.0019599	total: 2m 43s	remaining: 5.06s
# 970:	learn: 0.0019599	total: 2m 43s	remaining: 4.89s
# 971:	learn: 0.0019599	total: 2m 44s	remaining: 4.73s
# 972:	learn: 0.0019599	total: 2m 44s	remaining: 4.56s
# 973:	learn: 0.0019598	total: 2m 44s	remaining: 4.39s
# 974:	learn: 0.0019597	total: 2m 44s	remaining: 4.22s
# 975:	learn: 0.0019597	total: 2m 44s	remaining: 4.05s
# 976:	learn: 0.0019597	total: 2m 45s	remaining: 3.89s
# 977:	learn: 0.0019597	total: 2m 45s	remaining: 3.72s
# 978:	learn: 0.0019596	total: 2m 45s	remaining: 3.55s
# 979:	learn: 0.0019596	total: 2m 45s	remaining: 3.38s
# 980:	learn: 0.0019596	total: 2m 45s	remaining: 3.21s
# 981:	learn: 0.0019596	total: 2m 46s	remaining: 3.04s
# 982:	learn: 0.0019596	total: 2m 46s	remaining: 2.88s
# 983:	learn: 0.0019595	total: 2m 46s	remaining: 2.71s
# 984:	learn: 0.0019595	total: 2m 46s	remaining: 2.54s
# 985:	learn: 0.0019595	total: 2m 46s	remaining: 2.37s
# 986:	learn: 0.0019595	total: 2m 47s	remaining: 2.2s
# 987:	learn: 0.0019595	total: 2m 47s	remaining: 2.03s
# 988:	learn: 0.0019594	total: 2m 47s	remaining: 1.86s
# 989:	learn: 0.0019594	total: 2m 47s	remaining: 1.69s
# 990:	learn: 0.0019594	total: 2m 47s	remaining: 1.52s
# 991:	learn: 0.0019593	total: 2m 48s	remaining: 1.36s
# 992:	learn: 0.0019593	total: 2m 48s	remaining: 1.19s
# 993:	learn: 0.0019593	total: 2m 48s	remaining: 1.02s
# 994:	learn: 0.0019592	total: 2m 48s	remaining: 848ms
# 995:	learn: 0.0019592	total: 2m 48s	remaining: 679ms
# 996:	learn: 0.0019592	total: 2m 49s	remaining: 509ms
# 997:	learn: 0.0019591	total: 2m 49s	remaining: 339ms
# 998:	learn: 0.0019591	total: 2m 49s	remaining: 170ms
# 999:	learn: 0.0019591	total: 2m 49s	remaining: 0us

# %%
# Evaluation metrics for Adaboost Regressor
MSE_eval_score_CATBOOST_regressor , R2_eval_score_CATBOOST_regressor = model_eval_scores(y_test,y_pred_CATBOOST_regressor)
# Out:
# Mean Squared  Error :  4.007074174767325e-06
# Mean Absolute Error :  0.001234504335636526
# R2 Score            :  0.01838275076514695

# %%
print(y_test.shape)
print(y_pred_CATBOOST_regressor.shape)
x = np.arange(len(y_test))
# Out:
# (391196,)
# (391196,)

# %%
# Appending the Model and Validation Score in a stored list
update_scores( MSE_eval_score_CATBOOST_regressor , R2_eval_score_CATBOOST_regressor ,'CATBOOST_Regressor')

# %%
# Calling the function to view the list of machine learning models executed till now and their respective scores
view_scores()
# Out:
# The scores are:
#
# +--------------------------+-----------------------+-----------------------+
# |          Model           |  Mean Squared  Error  |        R2 Score       |
# +--------------------------+-----------------------+-----------------------+
# |     LinearRegression     | 4.077768814176103e-06 | 0.0010646092869888157 |
# |       DecisionTree       | 7.946220155825404e-06 |  -0.9465940561553996  |
# |       GridSearchCV       | 4.076280981000996e-06 | 0.0014290853722748187 |
# |       RandomForest       | 4.071814065767409e-06 |  0.002523350377841793 |
# |        KNeighbors        | 4.528346542971248e-06 |  -0.10931389917475176 |
# |    Adaboost_Regressor    | 1.893919327645558e-05 |   -3.639554446940342  |
# | Gradient_boost_Regressor | 4.051445837256448e-06 |  0.007512977115629149 |
# |    XGboost_Regressor     | 4.012689507663918e-06 |  0.017007156655559297 |
# |      LGBM_Regressor      | 4.030760195289275e-06 |  0.012580360967502258 |
# |    CATBOOST_Regressor    | 4.007074174767325e-06 |  0.01838275076514695  |
# +--------------------------+-----------------------+-----------------------+

# %%
# plot lines 
plt.plot( x , y_test , label = "y test" )
plt.plot( x , y_pred_CATBOOST_regressor, label = "y predicted" )
plt.legend() 
plt.show()

# %% [markdown]
# # 10. Regression using ANN

# %%
def build_model():
    model=keras.Sequential([Dense(16, activation='relu'),Dense(16, activation='relu'),
                                                 Dense(1)])
    optimizer=tf.keras.optimizers.RMSprop(0.001)
    model.compile(loss='mse', optimizer=optimizer, metrics=['mae','mse'])
    return model

# %%
ANN_regressor = build_model()

# %%
ANN_regressor.fit( X_train , y_train , epochs = 20 )
# Out:
# Epoch 1/20
# 48900/48900 [==============================] - 93s 2ms/step - loss: 4.9344e-06 - mae: 0.0014 - mse: 4.9344e-06
# Epoch 2/20
# 48900/48900 [==============================] - 93s 2ms/step - loss: 4.4318e-06 - mae: 0.0014 - mse: 4.4318e-06
# Epoch 3/20
# 48900/48900 [==============================] - 88s 2ms/step - loss: 4.3910e-06 - mae: 0.0013 - mse: 4.3910e-06
# Epoch 4/20
# 48900/48900 [==============================] - 97s 2ms/step - loss: 4.3733e-06 - mae: 0.0013 - mse: 4.3733e-06
# Epoch 5/20
# 48900/48900 [==============================] - 92s 2ms/step - loss: 4.3695e-06 - mae: 0.0013 - mse: 4.3695e-06
# Epoch 6/20
# 48900/48900 [==============================] - 91s 2ms/step - loss: 4.3690e-06 - mae: 0.0013 - mse: 4.3690e-06
# Epoch 7/20
# 48900/48900 [==============================] - 95s 2ms/step - loss: 4.3633e-06 - mae: 0.0013 - mse: 4.3633e-06
# Epoch 8/20
# 48900/48900 [==============================] - 90s 2ms/step - loss: 4.3644e-06 - mae: 0.0013 - mse: 4.3644e-06
# Epoch 9/20
# 48900/48900 [==============================] - 104s 2ms/step - loss: 4.3607e-06 - mae: 0.0013 - mse: 4.3607e-06
# Epoch 10/20
# 48900/48900 [==============================] - 117s 2ms/step - loss: 4.3626e-06 - mae: 0.0013 - mse: 4.3626e-06
# Epoch 11/20
# 48900/48900 [==============================] - 97s 2ms/step - loss: 4.3630e-06 - mae: 0.0013 - mse: 4.3630e-06
# Epoch 12/20
# 48900/48900 [==============================] - 94s 2ms/step - loss: 4.3606e-06 - mae: 0.0013 - mse: 4.3606e-06
# Epoch 13/20
# 48900/48900 [==============================] - 97s 2ms/step - loss: 4.3575e-06 - mae: 0.0013 - mse: 4.3575e-06
# Epoch 14/20
# 48900/48900 [==============================] - 96s 2ms/step - loss: 4.3591e-06 - mae: 0.0013 - mse: 4.3591e-06
# Epoch 15/20
# 48900/48900 [==============================] - 97s 2ms/step - loss: 4.3557e-06 - mae: 0.0013 - mse: 4.3557e-06
# Epoch 16/20
# 48900/48900 [==============================] - 98s 2ms/step - loss: 4.3593e-06 - mae: 0.0013 - mse: 4.3593e-06
# Epoch 17/20
# 48900/48900 [==============================] - 97s 2ms/step - loss: 4.3562e-06 - mae: 0.0013 - mse: 4.3562e-06
# Epoch 18/20
# 48900/48900 [==============================] - 98s 2ms/step - loss: 4.3553e-06 - mae: 0.0013 - mse: 4.3553e-06
# Epoch 19/20
# 48900/48900 [==============================] - 96s 2ms/step - loss: 4.3560e-06 - mae: 0.0013 - mse: 4.3560e-06
# Epoch 20/20
# 48900/48900 [==============================] - 97s 2ms/step - loss: 4.3574e-06 - mae: 0.0013 - mse: 4.3574e-06

# %%
y_pred_ANN_regressor = ANN_regressor.predict(X_test)
# Out:
# 12225/12225 [==============================] - 18s 1ms/step

# %%
# Evaluation metrics for ANN Regressor
MSE_eval_score_ANN_regressor , R2_eval_score_ANN_regressor = model_eval_scores(y_test,y_pred_ANN_regressor)
# Out:
# Mean Squared  Error :  4.181315939119983e-06
# Mean Absolute Error :  0.0012789498539906726
# R2 Score            :  -0.024301440733657698

# %%
print(y_test.shape)
print(y_pred_ANN_regressor.shape)
x = np.arange(len(y_test))
# Out:
# (391196,)
# (391196, 1)

# %%
# Appending the Model and Validation Score in a stored list
update_scores( MSE_eval_score_ANN_regressor , R2_eval_score_ANN_regressor ,'ANN_Regressor')

# %%
# Calling the function to view the list of machine learning models executed till now and their respective scores
view_scores()
# Out:
# The scores are:
#
# +---------------+-----------------------+-----------------------+
# |     Model     |  Mean Squared  Error  |        R2 Score       |
# +---------------+-----------------------+-----------------------+
# | ANN_Regressor | 4.181315939119983e-06 | -0.024301440733657698 |
# +---------------+-----------------------+-----------------------+

# %%
# plot lines 
plt.plot( x , y_test , label = "y test" )
plt.plot( x , y_pred_ANN_regressor, label = "y predicted" )
plt.legend() 
plt.show()

# %% [markdown]
# # 11. Recurrent Neural Network

# %%
# Reshape the input data for RNN
X_train_rnn = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test_rnn = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# Define a function to build the RNN model
def build_rnn_model(input_shape):
    model = keras.Sequential([
        keras.layers.SimpleRNN(units=64, input_shape=input_shape, activation='relu'),
        keras.layers.Dense(512, activation='relu'),
        keras.layers.Dense(512, activation='relu'),
        keras.layers.Dense(256, activation='relu'),
        keras.layers.Dense(128, activation='relu'),
        keras.layers.Dense(64, activation='relu'),
        keras.layers.Dense(32, activation='relu'),
        keras.layers.Dense(1, activation='relu')  # regression
    ])
    return model

# %%
# Build the RNN model
RNN_model = build_rnn_model(input_shape=(X_train_rnn.shape[1], X_train_rnn.shape[2]))

# %%
# Compile the model
RNN_model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mse','mae'])
RNN_model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_2 (SimpleRNN)    (None, 64)                4224
#
#  dense_29 (Dense)            (None, 512)               33280
#
#  dense_30 (Dense)            (None, 512)               262656
#
#  dense_31 (Dense)            (None, 256)               131328
#
#  dense_32 (Dense)            (None, 128)               32896
#
#  dense_33 (Dense)            (None, 64)                8256
#
#  dense_34 (Dense)            (None, 32)                2080
#
#  dense_35 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 474753 (1.81 MB)
# Trainable params: 474753 (1.81 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
RNN_model.fit( X_train_rnn , y_train , epochs = 20 )
# Out:
# Epoch 1/20
# 48900/48900 [==============================] - 322s 7ms/step - loss: 4.0485e-06 - mse: 4.0485e-06 - mae: 0.0012
# Epoch 2/20
# 48900/48900 [==============================] - 342s 7ms/step - loss: 4.0485e-06 - mse: 4.0485e-06 - mae: 0.0012
# Epoch 3/20
# 48900/48900 [==============================] - 343s 7ms/step - loss: 4.0484e-06 - mse: 4.0484e-06 - mae: 0.0012
# Epoch 4/20
# 48900/48900 [==============================] - 322s 7ms/step - loss: 4.0485e-06 - mse: 4.0485e-06 - mae: 0.0012
# Epoch 5/20
# 48900/48900 [==============================] - 326s 7ms/step - loss: 4.0485e-06 - mse: 4.0485e-06 - mae: 0.0012
# Epoch 6/20
# 48900/48900 [==============================] - 318s 7ms/step - loss: 4.0485e-06 - mse: 4.0485e-06 - mae: 0.0012
# Epoch 7/20
# 48900/48900 [==============================] - 326s 7ms/step - loss: 4.0485e-06 - mse: 4.0485e-06 - mae: 0.0012
# Epoch 8/20
# 48900/48900 [==============================] - 321s 7ms/step - loss: 4.0485e-06 - mse: 4.0485e-06 - mae: 0.0012
# Epoch 9/20
# 48900/48900 [==============================] - 339s 7ms/step - loss: 4.0485e-06 - mse: 4.0485e-06 - mae: 0.0012
# Epoch 10/20
# 48900/48900 [==============================] - 352s 7ms/step - loss: 4.0485e-06 - mse: 4.0485e-06 - mae: 0.0012
# Epoch 11/20
# 48900/48900 [==============================] - 334s 7ms/step - loss: 4.0485e-06 - mse: 4.0485e-06 - mae: 0.0012
# Epoch 12/20
# 48900/48900 [==============================] - 338s 7ms/step - loss: 4.0485e-06 - mse: 4.0485e-06 - mae: 0.0012
# Epoch 13/20
# 48900/48900 [==============================] - 342s 7ms/step - loss: 4.0485e-06 - mse: 4.0485e-06 - mae: 0.0012
# Epoch 14/20
# 48900/48900 [==============================] - 331s 7ms/step - loss: 4.0485e-06 - mse: 4.0485e-06 - mae: 0.0012
# Epoch 15/20
# 48900/48900 [==============================] - 318s 7ms/step - loss: 4.0485e-06 - mse: 4.0485e-06 - mae: 0.0012
# Epoch 16/20
# 48900/48900 [==============================] - 362s 7ms/step - loss: 4.0485e-06 - mse: 4.0485e-06 - mae: 0.0012
# Epoch 17/20
# 48900/48900 [==============================] - 345s 7ms/step - loss: 4.0485e-06 - mse: 4.0485e-06 - mae: 0.0012
# Epoch 18/20
# 48900/48900 [==============================] - 322s 7ms/step - loss: 4.0485e-06 - mse: 4.0485e-06 - mae: 0.0012
# Epoch 19/20
# 48900/48900 [==============================] - 322s 7ms/step - loss: 4.0485e-06 - mse: 4.0485e-06 - mae: 0.0012
# Epoch 20/20
# 48900/48900 [==============================] - 326s 7ms/step - loss: 4.0485e-06 - mse: 4.0485e-06 - mae: 0.0012

# %%
y_pred_RNN_model = RNN_model.predict(X_test)
# Out:
# 12225/12225 [==============================] - 25s 2ms/step

# %%
# Evaluation metrics for RNN Regressor
MSE_eval_score_RNN , R2_eval_score_RNN = model_eval_scores(y_test,y_pred_RNN_model)
# Out:
# Mean Squared  Error :  4.082143746729277e-06
# Mean Absolute Error :  0.0012387662353933243
# R2 Score            :  -7.122622911248655e-06

# %%
print(y_test.shape)
print(y_pred_RNN_model.shape)
x = np.arange(len(y_test))
# Out:
# (391196,)
# (391196, 1)

# %%
# Appending the Model and Validation Score in a stored list
update_scores( MSE_eval_score_RNN , R2_eval_score_RNN ,'RNN_Regressor')

# %%
# Calling the function to view the list of machine learning models executed till now and their respective scores
view_scores()
# Out:
# The scores are:
#
# +---------------+-----------------------+------------------------+
# |     Model     |  Mean Squared  Error  |        R2 Score        |
# +---------------+-----------------------+------------------------+
# | RNN_Regressor | 4.082143746729277e-06 | -7.122622911248655e-06 |
# +---------------+-----------------------+------------------------+

# %%
# plot lines 
plt.plot( x , y_test , label = "y test" )
plt.plot( x , y_pred_RNN_model, label = "y predicted" )
plt.legend() 
plt.show()

# %% [markdown]
# # 12. Long Short Term Memory (LSTM)

# %%
# Reshape the input data for LSTM
X_train_lstm = X_train.reshape(X_train.shape[0], X_train.shape[1],1)
X_test_lstm = X_test.reshape(X_test.shape[0], X_test.shape[1],1)

print(X_train_lstm.shape)
print(y_train.shape)
# Build the LSTM model
LSTM_model = Sequential()
LSTM_model.add(LSTM(units=50, activation='relu', input_shape=(9, 1)))
LSTM_model.add(Dense(units=1))
# Out:
# (1564782, 9, 1)
# (1564782,)

# %%
# Compile the model
LSTM_model.compile(optimizer='adam', loss='mean_squared_error')
LSTM_model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_7 (LSTM)               (None, 50)                10400
#
#  dense_27 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 10451 (40.82 KB)
# Trainable params: 10451 (40.82 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#LSTM_model.fit( X_train , y_train )
LSTM_model.fit(X_train_lstm, y_train, epochs=20, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/20
# 39120/39120 [==============================] - 130s 3ms/step - loss: 5.4133e-06 - val_loss: 4.2950e-06
# Epoch 2/20
# 39120/39120 [==============================] - 129s 3ms/step - loss: 4.1909e-06 - val_loss: 4.1568e-06
# Epoch 3/20
# 39120/39120 [==============================] - 134s 3ms/step - loss: 4.1965e-06 - val_loss: 5.6192e-06
# Epoch 4/20
# 39120/39120 [==============================] - 123s 3ms/step - loss: 4.1912e-06 - val_loss: 4.0794e-06
# Epoch 5/20
# 39120/39120 [==============================] - 123s 3ms/step - loss: 4.1961e-06 - val_loss: 4.0254e-06
# Epoch 6/20
# 39120/39120 [==============================] - 123s 3ms/step - loss: 4.1943e-06 - val_loss: 4.1453e-06
# Epoch 7/20
# 39120/39120 [==============================] - 123s 3ms/step - loss: 4.1946e-06 - val_loss: 4.0477e-06
# Epoch 8/20
# 39120/39120 [==============================] - 125s 3ms/step - loss: 4.1958e-06 - val_loss: 4.0872e-06
# Epoch 9/20
# 39120/39120 [==============================] - 125s 3ms/step - loss: 4.1947e-06 - val_loss: 4.1157e-06
# Epoch 10/20
# 39120/39120 [==============================] - 125s 3ms/step - loss: 4.1968e-06 - val_loss: 3.9971e-06
# Epoch 11/20
# 39120/39120 [==============================] - 125s 3ms/step - loss: 4.1961e-06 - val_loss: 4.0275e-06
# Epoch 12/20
# 39120/39120 [==============================] - 124s 3ms/step - loss: 4.1949e-06 - val_loss: 4.1317e-06
# Epoch 13/20
# 39120/39120 [==============================] - 125s 3ms/step - loss: 4.1958e-06 - val_loss: 3.9885e-06
# Epoch 14/20
# 39120/39120 [==============================] - 126s 3ms/step - loss: 4.1951e-06 - val_loss: 4.0998e-06
# Epoch 15/20
# 39120/39120 [==============================] - 126s 3ms/step - loss: 4.1917e-06 - val_loss: 4.0202e-06
# Epoch 16/20
# 39120/39120 [==============================] - 126s 3ms/step - loss: 4.1936e-06 - val_loss: 4.0046e-06
# Epoch 17/20
# 39120/39120 [==============================] - 126s 3ms/step - loss: 4.1969e-06 - val_loss: 3.9950e-06
# Epoch 18/20
# 39120/39120 [==============================] - 126s 3ms/step - loss: 4.1958e-06 - val_loss: 3.9907e-06
# Epoch 19/20
# 39120/39120 [==============================] - 126s 3ms/step - loss: 4.1953e-06 - val_loss: 4.1423e-06
# Epoch 20/20
# 39120/39120 [==============================] - 125s 3ms/step - loss: 4.1963e-06 - val_loss: 4.2066e-06

# %%
y_pred_LSTM_model = LSTM_model.predict(X_test_lstm)
# Out:
# 12225/12225 [==============================] - 20s 2ms/step

# %%
# Evaluation metrics for LSMT
MSE_eval_score_LSTM , R2_eval_score_LSTM = model_eval_scores(y_test,y_pred_LSTM_model)
# Out:
# Mean Squared  Error :  4.297312514624986e-06
# Mean Absolute Error :  0.0013227765087748076
# R2 Score            :  -0.05271724598250738

# %%
print(y_test.shape)
print(y_pred_LSTM_model.shape)
x = np.arange(len(y_test))
# Out:
# (391196,)
# (391196, 1)

# %%
# Appending the Model and Validation Score in a stored list
update_scores( MSE_eval_score_LSTM , R2_eval_score_LSTM ,'LSTM_model')

# %%
# Calling the function to view the list of machine learning models executed till now and their respective scores
view_scores()
# Out:
# The scores are:
#
# +---------------+-----------------------+------------------------+
# |     Model     |  Mean Squared  Error  |        R2 Score        |
# +---------------+-----------------------+------------------------+
# | RNN_Regressor | 4.082143746729277e-06 | -7.122622911248655e-06 |
# |   LSTM_model  | 4.297312514624986e-06 |  -0.05271724598250738  |
# +---------------+-----------------------+------------------------+

# %%
# plot lines 
plt.plot( x , y_test , label = "y test" )
plt.plot( x , y_pred_LSTM_model, label = "y predicted" )
plt.legend() 
plt.show()
